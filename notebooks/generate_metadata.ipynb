# %% [markdown]
# # 테이블 메타데이터 생성
#
# 이 노트북은  테이블에 대한 통계 정보와 설명을 생성합니다.
#
# ## 작업 내용:
# 1. PostgreSQL 연결 및 테이블 스키마 확인
# 2. 테이블 통계 정보 수집
# 3. 컬럼별 통계 분석
# 4. Azure OpenAI를 활용한 설명 생성
# 5. 메타데이터 저장

# %%
# 1. 필요한 라이브러리 임포트
import os
import psycopg2
import pandas as pd
import numpy as np
from datetime import datetime
import json
from dotenv import load_dotenv
from openai import AzureOpenAI
from typing import Dict, List, Any
import warnings
warnings.filterwarnings('ignore')

# .env 파일 로드
load_dotenv()

print("라이브러리 임포트 완료")
# Out:
# 라이브러리 임포트 완료

# %%
# 2. PostgreSQL 연결 설정
def get_db_connection():
    """PostgreSQL 데이터베이스 연결"""
    try:
        conn = psycopg2.connect(
            host=os.getenv('PG_HOST'),
            port=os.getenv('PG_PORT'),
            database=os.getenv('PG_DATABASE'),
            user=os.getenv('PG_USER'),
            password=os.getenv('PG_PASSWORD')
        )
        print(f"✅ PostgreSQL 연결 성공: {os.getenv('PG_HOST')}")
        return conn
    except Exception as e:
        print(f"❌ PostgreSQL 연결 실패: {e}")
        return None

# 연결 테스트
conn = get_db_connection()
if conn:
    conn.close()
# Out:
# ✅ PostgreSQL 연결 성공: dev-rubicon-postgresql.postgres.database.azure.com

# %%
# 3. Azure OpenAI 클라이언트 설정
def get_openai_client():
    """Azure OpenAI 클라이언트 생성"""
    try:
        # 환경 변수 확인
        endpoint = os.getenv('ENDPOINT_URL')
        api_key = os.getenv('AZURE_OPENAI_API_KEY')
        api_version = os.getenv('AZURE_API_VERSION', '2024-02-01')  # 기본값 제공
        
        if not endpoint:
            print("❌ ENDPOINT_URL 환경 변수가 설정되지 않았습니다.")
            return None
        
        if not api_key:
            print("❌ AZURE_OPENAI_API_KEY 환경 변수가 설정되지 않았습니다.")
            return None
        
        # API 버전이 없으면 기본값 사용
        if not api_version:
            api_version = '2024-02-01'
            print(f"⚠️ AZURE_API_VERSION이 설정되지 않아 기본값 사용: {api_version}")
        
        print(f"📋 Azure OpenAI 설정:")
        print(f"  - Endpoint: {endpoint[:50]}...")
        print(f"  - API Version: {api_version}")
        print(f"  - Deployment: {os.getenv('DEPLOYMENT_NAME')}")
        
        client = AzureOpenAI(
            azure_endpoint=endpoint,
            api_key=api_key,
            api_version=api_version,
        )
        print(f"✅ Azure OpenAI 클라이언트 생성 성공")
        return client
    except Exception as e:
        print(f"❌ Azure OpenAI 클라이언트 생성 실패: {e}")
        return None

# 클라이언트 테스트
openai_client = get_openai_client()

# 간단한 테스트 호출
if openai_client:
    try:
        print("\n🧪 API 연결 테스트...")
        test_response = openai_client.chat.completions.create(
            model=os.getenv('DEPLOYMENT_NAME'),
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": "Say 'Hello' in one word."}
            ],
            max_tokens=10
        )
        if test_response and test_response.choices:
            print(f"✅ API 테스트 성공: '{test_response.choices[0].message.content}'")
        else:
            print("⚠️ API 응답이 비어있습니다.")
    except Exception as e:
        print(f"❌ API 테스트 실패: {e}")
        print(f"   상세 에러: {type(e).__name__}")
        if hasattr(e, '__dict__'):
            print(f"   에러 속성: {e.__dict__}")
# Out:
# 📋 Azure OpenAI 설정:
#   - Endpoint: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - API Version: 2025-01-01-preview
#   - Deployment: gpt-4.1
# ✅ Azure OpenAI 클라이언트 생성 성공
#
# 🧪 API 연결 테스트...
# ✅ API 테스트 성공: 'Hello'

# %%
# 4. 테이블 스키마 정보 조회
def get_table_schema(table_name='test'):
    """테이블 스키마 정보 조회 (코멘트 포함)"""
    conn = get_db_connection()
    if not conn:
        return None
    
    try:
        # PostgreSQL에서 컬럼 정보와 코멘트를 함께 조회
        query = """
        SELECT 
            c.column_name,
            c.data_type,
            c.character_maximum_length,
            c.numeric_precision,
            c.numeric_scale,
            c.is_nullable,
            c.column_default,
            pgd.description as column_comment
        FROM information_schema.columns c
        LEFT JOIN pg_catalog.pg_statio_all_tables as st
            ON c.table_schema = st.schemaname 
            AND c.table_name = st.relname
        LEFT JOIN pg_catalog.pg_description pgd 
            ON pgd.objoid = st.relid 
            AND pgd.objsubid = c.ordinal_position
        WHERE c.table_schema = 'public' 
        AND c.table_name = %s
        ORDER BY c.ordinal_position;
        """
        
        df_schema = pd.read_sql_query(query, conn, params=(table_name,))
        print(f"✅ 테이블 '{table_name}' 스키마 조회 성공")
        print(f"   - 컬럼 수: {len(df_schema)}")
        
        # 코멘트가 있는 컬럼 수 확인
        comment_count = df_schema['column_comment'].notna().sum()
        print(f"   - 코멘트가 있는 컬럼: {comment_count}개")
        
        return df_schema
    
    except Exception as e:
        print(f"❌ 테이블 스키마 조회 실패: {e}")
        return None
    
    finally:
        conn.close()

# 스키마 조회
df_schema = get_table_schema(table_name="kt_merged_product_20250929")
if df_schema is not None:
    print("\n테이블 스키마 정보:")
    display(df_schema.head(10))
# Out:
# ✅ PostgreSQL 연결 성공: dev-rubicon-postgresql.postgres.database.azure.com
# ✅ 테이블 'kt_merged_product_20250929' 스키마 조회 성공
#    - 컬럼 수: 34
#    - 코멘트가 있는 컬럼: 34개
#
# 테이블 스키마 정보:
#                column_name          data_type  character_maximum_length  \
# 0   display_category_major  character varying                    1000.0
# 1  display_category_middle  character varying                    1000.0
# 2   display_category_minor  character varying                    1000.0
# 3   product_category_major  character varying                    1000.0
# 4  product_category_middle  character varying                    1000.0
# 5   product_category_minor  character varying                    1000.0
# 6               model_name  character varying                    1000.0
# 7               model_code  character varying                    1000.0
# 8               product_id  character varying                    1000.0
# 9             product_name  character varying                    1000.0
#
#    numeric_precision  numeric_scale is_nullable column_default  \
# 0                NaN            NaN         YES           None
# 1                NaN            NaN         YES           None
# 2                NaN            NaN         YES           None
# 3                NaN            NaN         YES           None
# 4                NaN            NaN         YES           None
# 5                NaN            NaN         YES           None
# 6                NaN            NaN         YES           None
# 7                NaN            NaN         YES           None
# 8                NaN            NaN         YES           None
# 9                NaN            NaN         YES           None
#
#                                       column_comment
# 0  웹사이트에 노출되는 제품의 대분류 카테고리명입니다. (예: 모바일, TV & 오디오...
# 1  웹사이트에 노출되는 제품의 중분류 카테고리명입니다. (예: 스마트폰, QLED, 비...
# 2  웹사이트에 노출되는 제품의 소분류 카테고리명입니다. (예: Galaxy S, Neo...
# 3            내부 시스템에서 관리하는 제품의 대분류 카테고리 코드 또는 이름입니다.
# 4            내부 시스템에서 관리하는 제품의 중분류 카테고리 코드 또는 이름입니다.
# 5            내부 시스템에서 관리하는 제품의 소분류 카테고리 코드 또는 이름입니다.
# 6  제품의 공식 모델명입니다. 사용자가 일반적으로 인지하는 이름입니다. (예: Gala...
# 7  제품의 세부 사양(색상, 용량 등)을 포함하는 고유 모델 코드입니다. (예: SM-...
# 8                   데이터베이스에서 각 제품을 식별하기 위한 고유 ID입니다.
# 9  웹사이트에 최종적으로 표시되는 제품명입니다. (예: 갤럭시 S24 Ultra 자급제...

# %%
# 5. 테이블 기본 통계 정보 수집
def get_table_statistics(table_name='test'):
    """테이블 기본 통계 정보 수집"""
    conn = get_db_connection()
    if not conn:
        return None
    
    try:
        statistics = {}
        cursor = conn.cursor()
        
        # 테이블 행 수
        cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
        statistics['total_rows'] = cursor.fetchone()[0]
        
        # 테이블 크기
        cursor.execute(f"""
            SELECT pg_size_pretty(pg_relation_size('{table_name}')) as table_size,
                   pg_size_pretty(pg_total_relation_size('{table_name}')) as total_size
        """)
        size_info = cursor.fetchone()
        if size_info:
            statistics['table_size'] = size_info[0]
            statistics['total_size'] = size_info[1]
        
        # 테이블 통계 정보 (pg_stat_user_tables의 실제 컬럼명 사용)
        cursor.execute(f"""
            SELECT schemaname, relname, n_tup_ins, n_tup_upd, n_tup_del,
                   last_vacuum, last_autovacuum, last_analyze, last_autoanalyze
            FROM pg_stat_user_tables
            WHERE relname = '{table_name}'
        """)
        stat_info = cursor.fetchone()
        if stat_info:
            statistics['stats'] = {
                'schema': stat_info[0],
                'table': stat_info[1],
                'inserts': stat_info[2],
                'updates': stat_info[3],
                'deletes': stat_info[4],
                'last_vacuum': str(stat_info[5]) if stat_info[5] else None,
                'last_autovacuum': str(stat_info[6]) if stat_info[6] else None,
                'last_analyze': str(stat_info[7]) if stat_info[7] else None,
                'last_autoanalyze': str(stat_info[8]) if stat_info[8] else None
            }
        
        print(f"✅ 테이블 '{table_name}' 통계 정보 수집 완료")
        return statistics
    
    except Exception as e:
        print(f"❌ 테이블 통계 정보 수집 실패: {e}")
        # 에러 발생 시에도 기본 정보는 반환
        try:
            cursor = conn.cursor()
            cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
            count = cursor.fetchone()[0]
            return {'total_rows': count}
        except:
            return None
    
    finally:
        if 'cursor' in locals():
            cursor.close()
        conn.close()

# 통계 정보 수집
table_stats = get_table_statistics(table_name="kt_merged_product_20250929")
if table_stats:
    print("\n테이블 통계 정보:")
    print(json.dumps(table_stats, indent=2, default=str))
# Out:
# ✅ PostgreSQL 연결 성공: dev-rubicon-postgresql.postgres.database.azure.com
# ✅ 테이블 'kt_merged_product_20250929' 통계 정보 수집 완료
#
# 테이블 통계 정보:
# {
#   "total_rows": 2774,
#   "table_size": "2952 kB",
#   "total_size": "11 MB",
#   "stats": {
#     "schema": "public",
#     "table": "kt_merged_product_20250929",
#     "inserts": 2774,
#     "updates": 0,
#     "deletes": 0,
#     "last_vacuum": null,
#     "last_autovacuum": "2025-09-30 04:37:51.518091+00:00",
#     "last_analyze": null,
#     "last_autoanalyze": "2025-09-30 04:37:59.005526+00:00"
#   }
# }

# %%
# 6. 컬럼별 상세 통계 분석
def get_column_statistics(table_name='test', sample_size=10000):
    """컬럼별 상세 통계 정보 수집"""
    conn = get_db_connection()
    if not conn:
        return None

    try:
        # 먼저 테이블에 데이터가 있는지 확인
        cursor = conn.cursor()
        cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
        total_rows = cursor.fetchone()[0]

        if total_rows == 0:
            print(f"⚠️ 테이블 '{table_name}'에 데이터가 없습니다.")
            return None

        # 샘플 크기 조정 (전체 행 수보다 크면 전체 행 수로 조정)
        actual_sample_size = min(sample_size, total_rows)

        # 샘플 데이터 로드
        query = f"SELECT * FROM {table_name} LIMIT {actual_sample_size}"
        df = pd.read_sql_query(query, conn)

        column_stats = []

        for col in df.columns:
            stats = {
                'column_name': col,
                'data_type': str(df[col].dtype),
                'non_null_count': int(df[col].notna().sum()),
                'null_count': int(df[col].isna().sum()),
                'null_ratio': f"{df[col].isna().mean() * 100:.2f}%",
                # 기본적으로 모든 통계 값을 None으로 초기화
                'min': None,
                'max': None,
                'mean': None,
                'median': None,
                'std': None,
                'values': None  # 새로 추가된 컬럼
            }
            
            # 스키마 정보에서 코멘트 추가
            if df_schema is not None and 'column_comment' in df_schema.columns:
                schema_row = df_schema[df_schema['column_name'] == col]
                if not schema_row.empty:
                    stats['column_comment'] = schema_row.iloc[0]['column_comment']
                else:
                    stats['column_comment'] = None
            else:
                stats['column_comment'] = None

            # unique_count 계산 시 에러 처리
            try:
                # JSON/JSONB 컬럼이나 복잡한 객체가 포함된 경우를 처리
                if df[col].dtype == 'object':
                    # 문자열로 변환하여 고유값 계산
                    unique_count = df[col].astype(str).nunique()
                else:
                    unique_count = df[col].nunique()

                stats['unique_count'] = int(unique_count)
                stats['unique_ratio'] = f"{unique_count / len(df) * 100:.2f}%"
            except Exception as e:
                # 에러 발생 시 기본값 설정
                stats['unique_count'] = None
                stats['unique_ratio'] = None
                print(f"  ⚠️ 컬럼 '{col}' unique_count 계산 실패: {e}")

            # 수치형 데이터 통계 (숫자형 컬럼에만 적용)
            if pd.api.types.is_numeric_dtype(df[col]):
                # null이 아닌 값만 추출
                non_null_values = df[col].dropna()
                if len(non_null_values) > 0:
                    try:
                        stats['min'] = float(non_null_values.min())
                    except:
                        stats['min'] = None

                    try:
                        stats['max'] = float(non_null_values.max())
                    except:
                        stats['max'] = None

                    try:
                        stats['mean'] = float(non_null_values.mean())
                    except:
                        stats['mean'] = None

                    try:
                        stats['median'] = float(non_null_values.median())
                    except:
                        stats['median'] = None

                    try:
                        # std는 샘플이 2개 이상일 때만 계산 가능
                        if len(non_null_values) > 1:
                            stats['std'] = float(non_null_values.std())
                        else:
                            stats['std'] = None
                    except:
                        stats['std'] = None
                    
                    # 수치형 데이터: 가장 높은 값 15개 추출
                    try:
                        top_15_values = non_null_values.nlargest(15).tolist()
                        stats['values'] = top_15_values
                    except:
                        stats['values'] = None
                else:
                    # non_null_values가 없으면 모든 통계 값은 이미 None으로 설정됨
                    pass

            # 문자열 및 객체 데이터 통계
            elif df[col].dtype == 'object':
                non_null_values = df[col].dropna()
                if len(non_null_values) > 0:
                    try:
                        # 문자열로 변환하여 길이 계산
                        str_values = non_null_values.astype(str)
                        str_lengths = str_values.str.len()

                        stats.update({
                            'min_length': int(str_lengths.min()) if len(str_lengths) > 0 else None,
                            'max_length': int(str_lengths.max()) if len(str_lengths) > 0 else None,
                            'avg_length': float(str_lengths.mean()) if len(str_lengths) > 0 else None
                        })

                        # most_common 계산 시 에러 처리 (3개에서 10개로 증가)
                        try:
                            # 복잡한 객체는 문자열로 변환하여 카운트
                            value_counts = df[col].astype(str).value_counts().head(10)
                            stats['most_common'] = value_counts.to_dict()
                        except:
                            stats['most_common'] = {}
                        
                        # nominal 데이터: 가장 많이 나오는 값 15개 추출
                        try:
                            top_15_frequent = df[col].value_counts().head(15).index.tolist()
                            stats['values'] = top_15_frequent
                        except:
                            stats['values'] = None

                    except Exception as e:
                        print(f"  ⚠️ 컬럼 '{col}' 문자열 통계 계산 실패: {e}")
                        stats.update({
                            'min_length': None,
                            'max_length': None,
                            'avg_length': None,
                            'most_common': {}
                        })
                else:
                    stats.update({
                        'min_length': None,
                        'max_length': None,
                        'avg_length': None,
                        'most_common': {}
                    })

            # 날짜형 데이터 통계
            elif pd.api.types.is_datetime64_any_dtype(df[col]):
                non_null_values = df[col].dropna()
                if len(non_null_values) > 0:
                    stats.update({
                        'min_date': str(non_null_values.min()),
                        'max_date': str(non_null_values.max()),
                        'date_range': str(non_null_values.max() - non_null_values.min())
                    })
                    
                    # 날짜형 데이터: 가장 최근 날짜 15개 추출
                    try:
                        recent_15_dates = non_null_values.nlargest(15).dt.strftime('%Y-%m-%d').tolist()
                        stats['values'] = recent_15_dates
                    except:
                        stats['values'] = None
                else:
                    stats.update({
                        'min_date': None,
                        'max_date': None,
                        'date_range': None
                    })

            column_stats.append(stats)

        print(f"✅ 컬럼별 통계 분석 완료 (샘플 크기: {len(df)}행)")
        return pd.DataFrame(column_stats)

    except Exception as e:
        print(f"❌ 컬럼별 통계 분석 실패: {e}")
        import traceback
        traceback.print_exc()
        return None

    finally:
        if 'cursor' in locals():
            cursor.close()
        conn.close()

# 컬럼 통계 수집
df_column_stats = get_column_statistics(table_name="kt_merged_product_20250929")
if df_column_stats is not None:
    print(f"\n총 {len(df_column_stats)}개 컬럼 분석 완료")
    print("\n컬럼별 통계 정보 (처음 20개):")
    display(df_column_stats.head(20))
# Out:
# ✅ PostgreSQL 연결 성공: dev-rubicon-postgresql.postgres.database.azure.com
# ✅ 컬럼별 통계 분석 완료 (샘플 크기: 2774행)
#
# 총 34개 컬럼 분석 완료
#
# 컬럼별 통계 정보 (처음 20개):
#                          column_name data_type  non_null_count  null_count  \
# 0             display_category_major    object            2774           0
# 1            display_category_middle    object            2774           0
# 2             display_category_minor    object            2774           0
# 3             product_category_major    object            2774           0
# 4            product_category_middle    object            2774           0
# 5             product_category_minor    object            2774           0
# 6                         model_name    object            2697          77
# 7                         model_code    object            2774           0
# 8                         product_id    object            2774           0
# 9                       product_name    object            2774           0
# 10                     product_color    object            2356         418
# 11                      release_date    object            2736          38
# 12       is_ai_subscription_eligible    object            2774           0
# 13    is_smart_subscription_eligible    object             173        2601
# 14           is_galaxy_club_eligible    object              46        2728
# 15  is_installment_payment_available    object            2774           0
# 16                product_detail_url    object            2774           0
# 17                      channel_code    object               0        2774
# 18              unique_selling_point    object            2666         108
# 19                      review_count   float64            2706          68
#
#    null_ratio  min     max       mean  median         std  \
# 0       0.00%  NaN     NaN        NaN     NaN         NaN
# 1       0.00%  NaN     NaN        NaN     NaN         NaN
# 2       0.00%  NaN     NaN        NaN     NaN         NaN
# 3       0.00%  NaN     NaN        NaN     NaN         NaN
# 4       0.00%  NaN     NaN        NaN     NaN         NaN
# 5       0.00%  NaN     NaN        NaN     NaN         NaN
# 6       2.78%  NaN     NaN        NaN     NaN         NaN
# 7       0.00%  NaN     NaN        NaN     NaN         NaN
# 8       0.00%  NaN     NaN        NaN     NaN         NaN
# 9       0.00%  NaN     NaN        NaN     NaN         NaN
# 10     15.07%  NaN     NaN        NaN     NaN         NaN
# 11      1.37%  NaN     NaN        NaN     NaN         NaN
# 12      0.00%  NaN     NaN        NaN     NaN         NaN
# 13     93.76%  NaN     NaN        NaN     NaN         NaN
# 14     98.34%  NaN     NaN        NaN     NaN         NaN
# 15      0.00%  NaN     NaN        NaN     NaN         NaN
# 16      0.00%  NaN     NaN        NaN     NaN         NaN
# 17    100.00%  NaN     NaN        NaN     NaN         NaN
# 18      3.89%  NaN     NaN        NaN     NaN         NaN
# 19      2.45%  0.0  8464.0  442.41833    20.0  1398.07926
#
#                                                values  \
# 0   [모바일, 리빙가전, TV, PC/주변기기, 주방가전, 오디오, 아울렛, MD 초이...
# 1   [갤럭시 액세서리, TV, 시스템에어컨, 갤럭시 스마트폰, 토너 및 잉크, 주방가전...
# 2   [케이스, 갤럭시 S, 상업용, QLED 4K TV, 갤럭시 워치 스트랩, 갤럭시 ...
# 3   [HHP, Flat Panel Displayer, AIR CONDITIONER, E...
# 4   [MOBILE-VPS PRODUCT, QLED TV, NEW RADIO MOBILE...
# 5   [Case, Air Conditioner, Cartridges, Panel, Mov...
# 6   [SM-S938N, SM-F741N, SM-F956N, SM-R530, SM-R63...
# 7   [JBLQUANTUM300BLK, SM-X520NZAAKOO, SM-X620NLBE...
# 8   [G000190421, G000433985, G000433968, G00043397...
# 9   [갤럭시 링, 갤럭시 S25 울트라 자급제, Bespoke AI 냉장고 4도어 90...
# 10  [블랙, 화이트, 블루, 그레이, 실버, 투명, 코타 화이트, 그레이지, 옐로우, ...
# 11  [2025-03-01, 2025-01-01, 2025-07-01, 2025-04-0...
# 12                                             [N, Y]
# 13                                             [Y, N]
# 14                                                [N]
# 15                                             [Y, N]
# 16  [https://www.samsung.com/sec/harman-life-style...
# 17                                               None
# 18  [{"다양한 패널로 완성하는 나만의 냉장고","인테리어에 따라 원하는 대로 교체 가...
# 19  [8464.0, 8464.0, 8464.0, 8085.0, 8085.0, 8085....
#
#                                        column_comment  unique_count  \
# 0   웹사이트에 노출되는 제품의 대분류 카테고리명입니다. (예: 모바일, TV & 오디오...             8
# 1   웹사이트에 노출되는 제품의 중분류 카테고리명입니다. (예: 스마트폰, QLED, 비...            41
# 2   웹사이트에 노출되는 제품의 소분류 카테고리명입니다. (예: Galaxy S, Neo...           183
# 3             내부 시스템에서 관리하는 제품의 대분류 카테고리 코드 또는 이름입니다.            20
# 4             내부 시스템에서 관리하는 제품의 중분류 카테고리 코드 또는 이름입니다.            80
# 5             내부 시스템에서 관리하는 제품의 소분류 카테고리 코드 또는 이름입니다.           200
# 6   제품의 공식 모델명입니다. 사용자가 일반적으로 인지하는 이름입니다. (예: Gala...          2120
# 7   제품의 세부 사양(색상, 용량 등)을 포함하는 고유 모델 코드입니다. (예: SM-...          2774
# 8                    데이터베이스에서 각 제품을 식별하기 위한 고유 ID입니다.          2774
# 9   웹사이트에 최종적으로 표시되는 제품명입니다. (예: 갤럭시 S24 Ultra 자급제...          1681
# 10                    제품의 색상명입니다. (예: 티타늄 블랙, 코튼 화이트)           241
# 11                                     제품의 공식 출시일입니다.            96
# 12  Galaxy AI와 같은 AI 관련 구독 서비스 가입 가능 여부를 나타냅니다. (T...             2
# 13  스마트 기기 구독 서비스(삼성닷컴 구독) 가입 가능 여부를 나타냅니다. (True/...             3
# 14      갤럭시 클럽 가입 또는 혜택 적용 가능 여부를 나타냅니다. (True/False)             2
# 15                   할부 결제 가능 여부를 나타냅니다. (True/False)             2
# 16                     제품의 상세 페이지로 연결되는 전체 URL 주소입니다.          2774
# 17          판매 채널을 구분하는 코드입니다. (예: 온라인, B2B, 특정 프로모션)             1
# 18  제품의 핵심 특장점을 요약한 문구 모음입니다. (예: 'Galaxy AI 탑재', ...           880
# 19                             해당 제품에 달린 리뷰의 총 개수입니다.           246
#
#    unique_ratio  min_length  max_length  avg_length  \
# 0         0.29%         2.0         8.0    3.782624
# 1         1.48%         2.0        18.0    6.776136
# 2         6.60%         2.0        31.0    8.112833
# 3         0.72%         2.0        34.0   10.736842
# 4         2.88%         2.0        32.0   13.322999
# 5         7.21%         2.0        29.0   11.080750
# 6        76.42%         1.0        18.0   10.537264
# 7       100.00%         5.0        18.0   12.701514
# 8       100.00%        10.0        10.0   10.000000
# 9        60.60%         3.0       120.0   28.925018
# 10        8.69%         1.0        37.0    4.208404
# 11        3.46%        10.0        10.0   10.000000
# 12        0.07%         1.0         1.0    1.000000
# 13        0.11%         1.0         1.0    1.000000
# 14        0.07%         1.0         1.0    1.000000
# 15        0.07%         1.0         1.0    1.000000
# 16      100.00%        53.0       138.0   83.071017
# 17        0.04%         NaN         NaN         NaN
# 18       31.72%         2.0       160.0   76.400975
# 19        8.87%         NaN         NaN         NaN
#
#                                           most_common
# 0   {'모바일': 813, '리빙가전': 592, 'TV': 430, 'PC/주변기기'...
# 1   {'갤럭시 액세서리': 455, 'TV': 347, '시스템에어컨': 192, '갤...
# 2   {'케이스': 269, '갤럭시 S': 109, '상업용': 102, 'QLED 4...
# 3   {'HHP': 804, 'Flat Panel Displayer': 430, 'AIR...
# 4   {'MOBILE-VPS PRODUCT': 354, 'QLED TV': 263, 'N...
# 5   {'Case': 241, 'Air Conditioner': 192, 'Cartrid...
# 6   {'None': 77, 'SM-S938N': 25, 'SM-F741N': 22, '...
# 7   {'JBLQUANTUM300BLK': 1, 'SM-X520NZAAKOO': 1, '...
# 8   {'G000190421': 1, 'G000433985': 1, 'G000433968...
# 9   {'갤럭시 링': 33, '갤럭시 S25 울트라 자급제': 12, 'Bespoke ...
# 10  {'블랙': 453, 'None': 418, '화이트': 299, '블루': 83,...
# 11  {'2025-03-01': 343, '2025-01-01': 226, '2025-0...
# 12                              {'N': 1847, 'Y': 927}
# 13                  {'None': 2601, 'Y': 127, 'N': 46}
# 14                            {'None': 2728, 'N': 46}
# 15                              {'Y': 2208, 'N': 566}
# 16  {'https://www.samsung.com/sec/harman-life-styl...
# 17                                                 {}
# 18  {'None': 108, '{"다양한 패널로 완성하는 나만의 냉장고","인테리어에 ...
# 19                                                NaN

# %%
display(df_column_stats.tail(20))
# Out:
#                          column_name data_type  non_null_count  null_count  \
# 14           is_galaxy_club_eligible    object              46        2728
# 15  is_installment_payment_available    object            2774           0
# 16                product_detail_url    object            2774           0
# 17                      channel_code    object               0        2774
# 18              unique_selling_point    object            2666         108
# 19                      review_count   float64            2706          68
# 20               review_rating_score   float64            2706          68
# 21                    standard_price   float64            2774           0
# 22                      member_price   float64            2774           0
# 23                     benefit_price   float64            1714        1060
# 24            review_text_collection    object            1757        1017
# 25             product_specification    object            2412         362
# 26                        is_on_sale    object               0        2774
# 27        web_coupon_discount_amount    object               0        2774
# 28                    stock_quantity   float64             498        2276
# 29       bundle_component_model_code    object             345        2429
# 30                         site_code    object            2774           0
# 31                       final_price   float64            2774           0
# 32                 is_bispokle_goods    object               0        2774
# 33                 is_bundle_product    object             345        2429
#
#    null_ratio     min         max          mean      median           std  \
# 14     98.34%     NaN         NaN           NaN         NaN           NaN
# 15      0.00%     NaN         NaN           NaN         NaN           NaN
# 16      0.00%     NaN         NaN           NaN         NaN           NaN
# 17    100.00%     NaN         NaN           NaN         NaN           NaN
# 18      3.89%     NaN         NaN           NaN         NaN           NaN
# 19      2.45%     0.0      8464.0  4.424183e+02       20.00  1.398079e+03
# 20      2.45%     0.0         5.0  3.723899e+00        4.67  1.902013e+00
# 21      0.00%  3300.0  52690000.0  1.890617e+06   676500.00  3.490187e+06
# 22      0.00%  3300.0  52690000.0  1.890277e+06   676500.00  3.490346e+06
# 23     38.21%  3000.0  50700000.0  2.177148e+06  1390000.00  3.172410e+06
# 24     36.66%     NaN         NaN           NaN         NaN           NaN
# 25     13.05%     NaN         NaN           NaN         NaN           NaN
# 26    100.00%     NaN         NaN           NaN         NaN           NaN
# 27    100.00%     NaN         NaN           NaN         NaN           NaN
# 28     82.05%     0.0      9999.0  3.086693e+03      146.50  4.453638e+03
# 29     87.56%     NaN         NaN           NaN         NaN           NaN
# 30      0.00%     NaN         NaN           NaN         NaN           NaN
# 31      0.00%  3000.0  50700000.0  1.523102e+06   569750.00  2.960212e+06
# 32    100.00%     NaN         NaN           NaN         NaN           NaN
# 33     87.56%     NaN         NaN           NaN         NaN           NaN
#
#                                                values  \
# 14                                                [N]
# 15                                             [Y, N]
# 16  [https://www.samsung.com/sec/harman-life-style...
# 17                                               None
# 18  [{"다양한 패널로 완성하는 나만의 냉장고","인테리어에 따라 원하는 대로 교체 가...
# 19  [8464.0, 8464.0, 8464.0, 8085.0, 8085.0, 8085....
# 20  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# 21  [52690000.0, 52390000.0, 50700000.0, 50467000....
# 22  [52690000.0, 52390000.0, 50700000.0, 50467000....
# 23  [50700000.0, 50400000.0, 47700000.0, 27000000....
# 24  [["깔끔한 디자인을 선호해서 만족합니다. 기능은 사용하기에 충분한 것 같아요. 갤...
# 25  [{'구분': ['냉방'], '냉방': ['0.070 kW', '0.35 A'], ...
# 26                                               None
# 27                                               None
# 28  [9999.0, 9999.0, 9999.0, 9999.0, 9999.0, 9999....
# 29  [{VCA-SPA90}, {EB-P4520XUEGKR,EF-PS937CJEGKR,E...
# 30                                              [B2C]
# 31  [50700000.0, 50700000.0, 50400000.0, 50400000....
# 32                                               None
# 33                                                [Y]
#
#                                        column_comment  unique_count  \
# 14      갤럭시 클럽 가입 또는 혜택 적용 가능 여부를 나타냅니다. (True/False)             2
# 15                   할부 결제 가능 여부를 나타냅니다. (True/False)             2
# 16                     제품의 상세 페이지로 연결되는 전체 URL 주소입니다.          2774
# 17          판매 채널을 구분하는 코드입니다. (예: 온라인, B2B, 특정 프로모션)             1
# 18  제품의 핵심 특장점을 요약한 문구 모음입니다. (예: 'Galaxy AI 탑재', ...           880
# 19                             해당 제품에 달린 리뷰의 총 개수입니다.           246
# 20                       해당 제품의 평균 리뷰 별점입니다. (예: 4.8)           122
# 21                             할인이 적용되지 않은 정상 판매가입니다.           968
# 22                            삼성닷컴 회원에게만 적용되는 할인가입니다.           966
# 23      즉시 할인, 쿠폰 등 모든 혜택이 적용된 최종 가격으로, '혜택가'에 해당합니다.           699
# 24                       사용자들이 작성한 리뷰 텍스트 데이터의 모음입니다.          1750
# 25     제품의 상세 기술 사양(스펙) 데이터입니다. (JSON 또는 구조화된 텍스트 형태)          2018
# 26      현재 제품이 세일 또는 프로모션 중인지 여부를 나타냅니다. (True/False)             1
# 27                              웹 쿠폰 적용 시 할인되는 금액입니다.             1
# 28                                   판매 가능한 재고 수량입니다.           204
# 29               번들(패키지) 상품일 경우, 구성품 각각의 모델 코드 목록입니다.           346
# 30          해당 상품이 판매되는 판매 채널에 대한 코드입니다. (예: B2C, FN)             1
# 31        모든 할인, 쿠폰, 카드사 혜택 등이 최종 반영된 실제 결제 예상 금액입니다.           933
# 32                          해당 제품의 비스포크 상품 여부를 나타냅니다.             1
# 33                            해당 제품의 번들 상품 여부를 나타냅니다.             2
#
#    unique_ratio  min_length  max_length   avg_length  \
# 14        0.07%         1.0         1.0     1.000000
# 15        0.07%         1.0         1.0     1.000000
# 16      100.00%        53.0       138.0    83.071017
# 17        0.04%         NaN         NaN          NaN
# 18       31.72%         2.0       160.0    76.400975
# 19        8.87%         NaN         NaN          NaN
# 20        4.40%         NaN         NaN          NaN
# 21       34.90%         NaN         NaN          NaN
# 22       34.82%         NaN         NaN          NaN
# 23       25.20%         NaN         NaN          NaN
# 24       63.09%         4.0     14285.0  2088.786568
# 25       72.75%        15.0      4681.0  1414.521973
# 26        0.04%         NaN         NaN          NaN
# 27        0.04%         NaN         NaN          NaN
# 28        7.35%         NaN         NaN          NaN
# 29       12.47%        11.0       145.0    46.507246
# 30        0.04%         3.0         3.0     3.000000
# 31       33.63%         NaN         NaN          NaN
# 32        0.04%         NaN         NaN          NaN
# 33        0.07%         1.0         1.0     1.000000
#
#                                           most_common
# 14                            {'None': 2728, 'N': 46}
# 15                              {'Y': 2208, 'N': 566}
# 16  {'https://www.samsung.com/sec/harman-life-styl...
# 17                                                 {}
# 18  {'None': 108, '{"다양한 패널로 완성하는 나만의 냉장고","인테리어에 ...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  {'None': 1017, '["깔끔한 디자인을 선호해서 만족합니다. 기능은 사용하...
# 25  {'None': 362, '{'구분': ['냉방'], '냉방': ['0.070 kW...
# 26                                                 {}
# 27                                                 {}
# 28                                                NaN
# 29  {'None': 2429, '{EB-P4520XUEGKR,EF-PS937CLEGKR...
# 30                                      {'B2C': 2774}
# 31                                                NaN
# 32                                                 {}
# 33                           {'None': 2429, 'Y': 345}

# %%
# 7. Azure OpenAI를 활용한 컬럼 설명 생성
def generate_column_description(column_info, table_context='test'):
    """Azure OpenAI를 사용하여 컬럼 설명 생성"""
    
    if not openai_client:
        print("⚠️ OpenAI 클라이언트가 초기화되지 않았습니다.")
        return None
    
    # 데이터 타입 확인
    data_type = column_info.get('data_type', '')
    is_numeric = any(dtype in data_type.lower() for dtype in ['int', 'float', 'numeric', 'decimal', 'double'])
    is_string = 'object' in data_type.lower() or 'varchar' in data_type.lower() or 'text' in data_type.lower()
    is_date = 'date' in data_type.lower() or 'time' in data_type.lower()
    
    # 기본 정보
    base_info = f"""
    테이블명: {table_context}
    컬럼 정보:
    - 컬럼명: {column_info.get('column_name')}
    - 데이터 타입: {column_info.get('data_type')}
    - NULL 비율: {column_info.get('null_ratio', 'N/A')}
    - 고유값 개수: {column_info.get('unique_count', 'N/A')}"""
    
    # 기존 코멘트가 있으면 추가
    column_comment = column_info.get('column_comment')
    if column_comment and column_comment != 'None' and pd.notna(column_comment):
        base_info += f"\n    - 기존 설명: {column_comment}"
    
    # 데이터 타입별 추가 정보
    type_specific_info = ""
    
    if is_numeric:
        # 숫자형 데이터인 경우
        min_val = column_info.get('min')
        max_val = column_info.get('max')
        mean_val = column_info.get('mean')
        median_val = column_info.get('median')
        std_val = column_info.get('std')
        
        if min_val is not None or max_val is not None or mean_val is not None:
            type_specific_info += "\n    - 통계 정보:"
            if min_val is not None:
                type_specific_info += f"\n      - 최소값: {min_val}"
            if max_val is not None:
                type_specific_info += f"\n      - 최대값: {max_val}"
            if mean_val is not None:
                type_specific_info += f"\n      - 평균: {mean_val:.2f}"
            if median_val is not None:
                type_specific_info += f"\n      - 중앙값: {median_val:.2f}"
            if std_val is not None:
                type_specific_info += f"\n      - 표준편차: {std_val:.2f}"
    
    elif is_string:
        # 문자열 데이터인 경우
        min_length = column_info.get('min_length')
        max_length = column_info.get('max_length')
        avg_length = column_info.get('avg_length')
        most_common = column_info.get('most_common', {})
        
        if min_length is not None or max_length is not None or avg_length is not None:
            type_specific_info += "\n    - 문자열 길이 정보:"
            if min_length is not None:
                type_specific_info += f"\n      - 최소 길이: {min_length}"
            if max_length is not None:
                type_specific_info += f"\n      - 최대 길이: {max_length}"
            if avg_length is not None:
                type_specific_info += f"\n      - 평균 길이: {avg_length:.1f}"
        
        if most_common and len(most_common) > 0:
            type_specific_info += "\n    - 가장 빈번한 값:"
            for value, count in list(most_common.items())[:3]:
                # 긴 문자열은 잘라서 표시
                display_value = value if len(str(value)) <= 30 else str(value)[:30] + "..."
                type_specific_info += f"\n      - '{display_value}': {count}개"
    
    elif is_date:
        # 날짜형 데이터인 경우
        min_date = column_info.get('min_date')
        max_date = column_info.get('max_date')
        date_range = column_info.get('date_range')
        
        if min_date or max_date or date_range:
            type_specific_info += "\n    - 날짜 범위:"
            if min_date:
                type_specific_info += f"\n      - 최소 날짜: {min_date}"
            if max_date:
                type_specific_info += f"\n      - 최대 날짜: {max_date}"
            if date_range:
                type_specific_info += f"\n      - 날짜 범위: {date_range}"
    
    # 프롬프트 구성 - 기존 코멘트가 있는 경우와 없는 경우를 구분
    if column_comment and column_comment != 'None' and pd.notna(column_comment):
        prompt = f"""{base_info}{type_specific_info}
    
    기존 설명을 참고하여 다음 형식으로 개선된 설명을 생성해주세요:
    1. 짧은 설명 (한 줄, 20자 이내) - 기존 설명을 참고하여 더 명확하게
    2. 상세 설명 (2-3줄, 비즈니스 의미 포함) - 기존 설명을 확장하여
    3. 데이터 특성 (NULL 허용 여부, 값 범위 등)
    
    기존 설명이 충분히 명확하다면 그대로 사용하되, 통계 정보를 반영하여 보완해주세요.
    """
    else:
        prompt = f"""{base_info}{type_specific_info}
    
    다음 형식으로 응답해주세요:
    1. 짧은 설명 (한 줄, 20자 이내)
    2. 상세 설명 (2-3줄, 비즈니스 의미 포함)
    3. 데이터 특성 (NULL 허용 여부, 값 범위 등)
    """
    
    try:
        print(f"\n📝 API 요청 정보:")
        print(f"  - 모델: {os.getenv('DEPLOYMENT_NAME')}")
        print(f"  - 엔드포인트: {os.getenv('ENDPOINT_URL')[:50]}...")
        
        # 프롬프트 일부 출력 (디버깅용)
        print(f"  - 프롬프트 길이: {len(prompt)}자")
        print(f"  - 프롬프트 처음 200자:\n{prompt[:200]}...")
        
        response = openai_client.chat.completions.create(
            model=os.getenv('DEPLOYMENT_NAME'),
            messages=[
                {"role": "system", "content": "당신은 데이터베이스 전문가입니다. 컬럼의 비즈니스 의미를 명확하게 설명해주세요. 기존 코멘트가 있다면 이를 참고하여 개선된 설명을 제공하세요."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=3000,
            temperature=1,
            # temperature 제거 (gpt-5-01 모델에서 지원 안 할 수 있음)
        )
        
        # 전체 응답 객체 확인
        print(f"\n📋 응답 객체 타입: {type(response)}")
        print(f"  - choices 개수: {len(response.choices) if response.choices else 0}")
        
        # 응답 확인
        if response and response.choices and len(response.choices) > 0:
            choice = response.choices[0]
            print(f"  - choice 객체: {choice}")
            print(f"  - finish_reason: {choice.finish_reason}")
            print(f"  - message 타입: {type(choice.message)}")
            
            # content 속성 확인
            if hasattr(choice.message, 'content'):
                content = choice.message.content
                print(f"  - content 타입: {type(content)}")
                print(f"  - content 값: '{content}'")
                
                if content:
                    print(f"✅ API 응답 수신 (길이: {len(content)}자)")
                    return content
                else:
                    print("⚠️ API 응답 content가 비어있습니다.")
                    # 빈 응답일 경우 기본 값 반환
                    if column_comment:
                        return f"1. {column_comment}\n2. {column_comment} 정보를 저장하는 컬럼입니다.\n3. NULL 허용, 문자열 타입"
                    else:
                        return f"1. {column_info.get('column_name')} 정보\n2. {column_info.get('column_name')} 관련 데이터를 저장합니다.\n3. {column_info.get('null_ratio')} NULL 비율"
            else:
                print("⚠️ message에 content 속성이 없습니다.")
                print(f"  - message 속성들: {dir(choice.message)}")
                return None
        else:
            print("⚠️ API 응답 형식이 예상과 다릅니다.")
            print(f"   응답 객체: {response}")
            return None
    
    except Exception as e:
        print(f"❌ OpenAI 설명 생성 실패: {e}")
        print(f"   에러 타입: {type(e).__name__}")
        if hasattr(e, 'response'):
            print(f"   응답 상태: {getattr(e.response, 'status_code', 'N/A')}")
            print(f"   응답 내용: {getattr(e.response, 'text', 'N/A')}")
        
        # 에러 발생 시 기본 설명 반환
        if column_comment:
            return f"1. {column_comment}\n2. {column_comment} 정보를 저장하는 컬럼입니다.\n3. NULL 허용 여부 확인 필요"
        else:
            return f"1. {column_info.get('column_name')} 컬럼\n2. 상세 설명 생성 실패\n3. 데이터 타입: {column_info.get('data_type')}"

# 테스트: 첫 번째 컬럼에 대한 설명 생성
if df_column_stats is not None and len(df_column_stats) > 0:
    print("=" * 60)
    print("테스트: 첫 번째 컬럼 설명 생성")
    print("=" * 60)
    
    test_column = df_column_stats.iloc[0].to_dict()
    print(f"\n테스트 컬럼 정보:")
    print(f"  - 컬럼명: {test_column.get('column_name')}")
    print(f"  - 데이터 타입: {test_column.get('data_type')}")
    print(f"  - 기존 코멘트: {test_column.get('column_comment')}")
    
    description = generate_column_description(test_column, table_context="kt_merged_product_20250929")
    
    print("\n" + "=" * 60)
    if description:
        print(f"생성된 설명:")
        print("-" * 50)
        print(description)
    else:
        print("⚠️ 설명 생성 실패 (None 반환)")
        
    # 추가 디버깅: 직접 API 호출 테스트
    print("\n" + "=" * 60)
    print("직접 API 테스트")
    print("=" * 60)
    
    if openai_client:
        try:
            print("간단한 메시지로 테스트 중...")
            test_response = openai_client.chat.completions.create(
                model=os.getenv('DEPLOYMENT_NAME'),
                messages=[
                    {"role": "system", "content": "You are a helpful assistant."},
                    {"role": "user", "content": "Say 'Hello World' in Korean."}
                ],
                max_completion_tokens=50
            )
            
            print(f"테스트 응답 타입: {type(test_response)}")
            if test_response.choices:
                print(f"Choices 개수: {len(test_response.choices)}")
                print(f"첫 번째 choice: {test_response.choices[0]}")
                print(f"Message: {test_response.choices[0].message}")
                print(f"Content: '{test_response.choices[0].message.content}'")
            else:
                print("No choices in response")
                
        except Exception as test_e:
            print(f"테스트 실패: {test_e}")
# Out:
# ============================================================
# 테스트: 첫 번째 컬럼 설명 생성
# ============================================================
#
# 테스트 컬럼 정보:
#   - 컬럼명: display_category_major
#   - 데이터 타입: object
#   - 기존 코멘트: 웹사이트에 노출되는 제품의 대분류 카테고리명입니다. (예: 모바일, TV & 오디오, 가전)
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 582자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: display_category_major
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 8
#     - 기존 설명: 웹사이트에 노출되는 제품의 대분류 카테고리명입니다. (예: 모바일, TV & 오디오...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n제품의 대분류 카테고리명\n\n2. 상세 설명  \ndisplay_category_major는 웹사이트에서 제품을 분류하는 주요 카테고리명을 나타내는 컬럼입니다. 예를 들어 '모바일', 'TV', '리빙가전' 등 8가지의 대분류가 사용되며, 고객이 제품을 쉽게 탐색할 수 있도록 분류 기준으로 활용됩니다. 이 컬럼을 기반으로 제품군별로 마케팅 및 판매 전략을 수립할 수 있습니다.\n\n3. 데이터 특성  \n- NULL 없음(0%)  \n- 값 범위: 8개 고유 카테고리명(최소 2자, 최대 8자)  \n- 대표 값: '모바일', '리빙가전', 'TV'  \n- 데이터 타입: object(문자열)", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 제품의 대분류 카테고리명
#
# 2. 상세 설명
# display_category_major는 웹사이트에서 제품을 분류하는 주요 카테고리명을 나타내는 컬럼입니다. 예를 들어 '모바일', 'TV', '리빙가전' 등 8가지의 대분류가 사용되며, 고객이 제품을 쉽게 탐색할 수 있도록 분류 기준으로 활용됩니다. 이 컬럼을 기반으로 제품군별로 마케팅 및 판매 전략을 수립할 수 있습니다.
#
# 3. 데이터 특성
# - NULL 없음(0%)
# - 값 범위: 8개 고유 카테고리명(최소 2자, 최대 8자)
# - 대표 값: '모바일', '리빙가전', 'TV'
# - 데이터 타입: object(문자열)'
# ✅ API 응답 수신 (길이: 337자)
#
# ============================================================
# 생성된 설명:
# --------------------------------------------------
# 1. 짧은 설명
# 제품의 대분류 카테고리명
#
# 2. 상세 설명
# display_category_major는 웹사이트에서 제품을 분류하는 주요 카테고리명을 나타내는 컬럼입니다. 예를 들어 '모바일', 'TV', '리빙가전' 등 8가지의 대분류가 사용되며, 고객이 제품을 쉽게 탐색할 수 있도록 분류 기준으로 활용됩니다. 이 컬럼을 기반으로 제품군별로 마케팅 및 판매 전략을 수립할 수 있습니다.
#
# 3. 데이터 특성
# - NULL 없음(0%)
# - 값 범위: 8개 고유 카테고리명(최소 2자, 최대 8자)
# - 대표 값: '모바일', '리빙가전', 'TV'
# - 데이터 타입: object(문자열)
#
# ============================================================
# 직접 API 테스트
# ============================================================
# 간단한 메시지로 테스트 중...
# 테스트 응답 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
# Choices 개수: 1
# 첫 번째 choice: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='"Hello World" in Korean is:\n\n안녕하세요, 세계! (annyeonghaseyo, segye!)\n\nHere, "안녕하세요" means "Hello," and "세계" means "World."', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
# Message: ChatCompletionMessage(content='"Hello World" in Korean is:\n\n안녕하세요, 세계! (annyeonghaseyo, segye!)\n\nHere, "안녕하세요" means "Hello," and "세계" means "World."', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)
# Content: '"Hello World" in Korean is:
#
# 안녕하세요, 세계! (annyeonghaseyo, segye!)
#
# Here, "안녕하세요" means "Hello," and "세계" means "World."'

# %%
# 8. 모든 컬럼에 대한 메타데이터 생성 (배치 처리)
def generate_all_column_metadata(df_stats, batch_size=5):
    """모든 컬럼에 대한 메타데이터 생성"""
    
    if df_stats is None or len(df_stats) == 0:
        print("❌ 컬럼 통계 정보가 없습니다.")
        return None
    
    metadata_list = []
    total_columns = len(df_stats)
    
    print(f"총 {total_columns}개 컬럼에 대한 메타데이터 생성 시작...")
    
    for i in range(0, total_columns, batch_size):
        batch_end = min(i + batch_size, total_columns)
        print(f"\n배치 처리: {i+1}-{batch_end}/{total_columns}")
        
        for idx in range(i, batch_end):
            column_info = df_stats.iloc[idx].to_dict()
            column_name = column_info['column_name']
            
            print(f"  - {column_name} 처리 중...")
            
            # OpenAI 설명 생성
            description = generate_column_description(column_info, table_context="kt_merged_product_20250929")
            
            # 메타데이터 구성
            metadata = {
                'column_name': column_name,
                'data_type': column_info.get('data_type'),
                'null_ratio': column_info.get('null_ratio'),
                'unique_count': column_info.get('unique_count'),
                'description': description,
                'generated_at': datetime.now().isoformat()
            }
            
            # 수치형 데이터 추가 정보
            if 'min' in column_info:
                metadata.update({
                    'min': column_info.get('min'),
                    'max': column_info.get('max'),
                    'mean': column_info.get('mean'),
                    'median': column_info.get('median')
                })
            
            metadata_list.append(metadata)
            
            # API 호출 제한 방지를 위한 대기
            import time
            time.sleep(0.5)
    
    print(f"\n✅ 총 {len(metadata_list)}개 컬럼 메타데이터 생성 완료")
    return pd.DataFrame(metadata_list)

# 메타데이터 생성 (처음 10개 컬럼만)
df_metadata = generate_all_column_metadata(df_column_stats)
if df_metadata is not None:
    print("\n생성된 메타데이터:")
    display(df_metadata)
# Out:
# 총 34개 컬럼에 대한 메타데이터 생성 시작...
#
# 배치 처리: 1-5/34
#   - display_category_major 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 582자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: display_category_major
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 8
#     - 기존 설명: 웹사이트에 노출되는 제품의 대분류 카테고리명입니다. (예: 모바일, TV & 오디오...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n제품의 대분류 카테고리명\n\n2. 상세 설명  \n웹사이트에서 노출되는 제품을 주요 분류 기준에 따라 구분한 대분류 카테고리명입니다. 예를 들어 '모바일', 'TV', '리빙가전' 등 다양한 제품군을 식별하며, 상품 분류 및 통계 분석에 활용됩니다.\n\n3. 데이터 특성  \n값은 NULL이 없으며, 총 8개의 고유 카테고리명만 존재합니다(예: 모바일, 리빙가전, TV 등). 데이터 타입은 문자열이며, 값의 길이는 2~8자 사이입니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 제품의 대분류 카테고리명
#
# 2. 상세 설명
# 웹사이트에서 노출되는 제품을 주요 분류 기준에 따라 구분한 대분류 카테고리명입니다. 예를 들어 '모바일', 'TV', '리빙가전' 등 다양한 제품군을 식별하며, 상품 분류 및 통계 분석에 활용됩니다.
#
# 3. 데이터 특성
# 값은 NULL이 없으며, 총 8개의 고유 카테고리명만 존재합니다(예: 모바일, 리빙가전, TV 등). 데이터 타입은 문자열이며, 값의 길이는 2~8자 사이입니다.'
# ✅ API 응답 수신 (길이: 252자)
#   - display_category_middle 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 591자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: display_category_middle
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 41
#     - 기존 설명: 웹사이트에 노출되는 제품의 중분류 카테고리명입니다. (예: 스마트폰, QLED,...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명:  \n제품 중분류 노출 카테고리명\n\n2. 상세 설명:  \n웹사이트에 노출되는 제품의 중분류 카테고리명을 나타냅니다. 'display_category_middle'은 제품을 고객이 쉽게 탐색할 수 있도록 스마트폰, TV, 갤럭시 액세서리 등 41개의 중분류로 구분하는 역할을 합니다. 비즈니스에서는 제품군별 마케팅, 상품 관리 및 분석에 활용됩니다.\n\n3. 데이터 특성:  \nNULL 값은 허용되지 않으며(0.00%), 현재 41개의 고유값이 존재합니다. 값의 문자열 길이는 최소 2자, 최대 18자, 평균 6.8자입니다. 가장 빈번한 값으로는 '갤럭시 액세서리'(455건), 'TV'(347건), '시스템에어컨'(192건)이 포함됩니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명:
# 제품 중분류 노출 카테고리명
#
# 2. 상세 설명:
# 웹사이트에 노출되는 제품의 중분류 카테고리명을 나타냅니다. 'display_category_middle'은 제품을 고객이 쉽게 탐색할 수 있도록 스마트폰, TV, 갤럭시 액세서리 등 41개의 중분류로 구분하는 역할을 합니다. 비즈니스에서는 제품군별 마케팅, 상품 관리 및 분석에 활용됩니다.
#
# 3. 데이터 특성:
# NULL 값은 허용되지 않으며(0.00%), 현재 41개의 고유값이 존재합니다. 값의 문자열 길이는 최소 2자, 최대 18자, 평균 6.8자입니다. 가장 빈번한 값으로는 '갤럭시 액세서리'(455건), 'TV'(347건), '시스템에어컨'(192건)이 포함됩니다.'
# ✅ API 응답 수신 (길이: 365자)
#   - display_category_minor 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 593자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: display_category_minor
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 183
#     - 기존 설명: 웹사이트에 노출되는 제품의 소분류 카테고리명입니다. (예: Galaxy S, N...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명 (한 줄, 20자 이내)  \n제품 소분류 카테고리명\n\n2. 상세 설명 (2-3줄, 비즈니스 의미 포함)  \ndisplay_category_minor 컬럼은 웹사이트에서 상품을 분류할 때 사용되는 소분류 카테고리명을 나타냅니다. 예시는 '케이스', '갤럭시 S', '상업용' 등으로, 고객이 원하는 제품군을 빠르게 찾을 수 있도록 도와줍니다. 비즈니스에서 제품 라인업 정렬 및 타깃별 마케팅 분석에 활용됩니다.\n\n3. 데이터 특성 (NULL 허용 여부, 값 범위 등)  \nNULL 값은 허용되지 않으며(0.00%), 총 183종의 고유 소분류명이 존재합니다. 문자열은 2~31자로 구성되어 있고, 데이터 대표값은 '케이스', '갤럭시 S', '상업용' 등입니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명 (한 줄, 20자 이내)
# 제품 소분류 카테고리명
#
# 2. 상세 설명 (2-3줄, 비즈니스 의미 포함)
# display_category_minor 컬럼은 웹사이트에서 상품을 분류할 때 사용되는 소분류 카테고리명을 나타냅니다. 예시는 '케이스', '갤럭시 S', '상업용' 등으로, 고객이 원하는 제품군을 빠르게 찾을 수 있도록 도와줍니다. 비즈니스에서 제품 라인업 정렬 및 타깃별 마케팅 분석에 활용됩니다.
#
# 3. 데이터 특성 (NULL 허용 여부, 값 범위 등)
# NULL 값은 허용되지 않으며(0.00%), 총 183종의 고유 소분류명이 존재합니다. 문자열은 2~31자로 구성되어 있고, 데이터 대표값은 '케이스', '갤럭시 S', '상업용' 등입니다.'
# ✅ API 응답 수신 (길이: 378자)
#   - product_category_major 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 602자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: product_category_major
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 20
#     - 기존 설명: 내부 시스템에서 관리하는 제품의 대분류 카테고리 코드 또는 이름입니다.
#     -...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. **짧은 설명 (20자 이내)**  \n제품 대분류 카테고리명\n\n2. **상세 설명**  \n내부 시스템에서 제품을 관리하기 위해 사용하는 주요 제품군(대분류)의 이름 또는 코드입니다.  \n이 컬럼은 상품을 유형별로 그룹화하여 분류 및 분석, 운영에 활용됩니다.  \n예를 들어 'HHP', 'Flat Panel Displayer', 'AIR CONDITIONER'와 같이 대표적인 제품군을 나타냅니다.\n\n3. **데이터 특성**  \n- NULL 값 없음 (0.00%)\n- 값은 총 20개로 한정된 대분류 코드 또는 이름\n- 문자열 길이는 최소 2자, 최대 34자, 평균 약 10.7자\n- 가장 빈번한 카테고리는 'HHP', 'Flat Panel Displayer', 'AIR CONDITIONER'임", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. **짧은 설명 (20자 이내)**
# 제품 대분류 카테고리명
#
# 2. **상세 설명**
# 내부 시스템에서 제품을 관리하기 위해 사용하는 주요 제품군(대분류)의 이름 또는 코드입니다.
# 이 컬럼은 상품을 유형별로 그룹화하여 분류 및 분석, 운영에 활용됩니다.
# 예를 들어 'HHP', 'Flat Panel Displayer', 'AIR CONDITIONER'와 같이 대표적인 제품군을 나타냅니다.
#
# 3. **데이터 특성**
# - NULL 값 없음 (0.00%)
# - 값은 총 20개로 한정된 대분류 코드 또는 이름
# - 문자열 길이는 최소 2자, 최대 34자, 평균 약 10.7자
# - 가장 빈번한 카테고리는 'HHP', 'Flat Panel Displayer', 'AIR CONDITIONER'임'
# ✅ API 응답 수신 (길이: 392자)
#   - product_category_middle 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 623자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: product_category_middle
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 80
#     - 기존 설명: 내부 시스템에서 관리하는 제품의 중분류 카테고리 코드 또는 이름입니다.
#     ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명 (20자 이내)  \n제품 중분류 카테고리명\n\n2. 상세 설명  \n내부 시스템에서 관리하는 제품의 중분류 카테고리 명칭 또는 코드입니다. 예를 들어 'QLED TV', 'MOBILE-VPS PRODUCT' 등 80종의 고유한 중분류 카테고리가 존재하며, 제품 분류 및 통계 분석에 활용됩니다. 비즈니스에서는 상품 마케팅, 판매 전략 수립 시 주요 기준으로 사용됩니다.\n\n3. 데이터 특성  \nNULL 값이 없으며(0.00%), 데이터는 최소 2자, 최대 32자의 문자열로 구성되어 있습니다. 총 80개의 고유값이 존재하고, 가장 빈번한 카테고리는 ‘MOBILE-VPS PRODUCT’, ‘QLED TV’ 등이 포함됩니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명 (20자 이내)
# 제품 중분류 카테고리명
#
# 2. 상세 설명
# 내부 시스템에서 관리하는 제품의 중분류 카테고리 명칭 또는 코드입니다. 예를 들어 'QLED TV', 'MOBILE-VPS PRODUCT' 등 80종의 고유한 중분류 카테고리가 존재하며, 제품 분류 및 통계 분석에 활용됩니다. 비즈니스에서는 상품 마케팅, 판매 전략 수립 시 주요 기준으로 사용됩니다.
#
# 3. 데이터 특성
# NULL 값이 없으며(0.00%), 데이터는 최소 2자, 최대 32자의 문자열로 구성되어 있습니다. 총 80개의 고유값이 존재하고, 가장 빈번한 카테고리는 ‘MOBILE-VPS PRODUCT’, ‘QLED TV’ 등이 포함됩니다.'
# ✅ API 응답 수신 (길이: 355자)
#
# 배치 처리: 6-10/34
#   - product_category_minor 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 594자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: product_category_minor
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 200
#     - 기존 설명: 내부 시스템에서 관리하는 제품의 소분류 카테고리 코드 또는 이름입니다.
#     ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명 (한 줄, 20자 이내)  \n제품 소분류 카테고리\n\n2. 상세 설명 (2-3줄, 비즈니스 의미 포함)  \n내부 시스템에서 각 제품을 더욱 세분화하기 위해 관리하는 제품의 소분류 카테고리 코드 또는 이름입니다. 제품군 내에서 응용, 기능, 용도 등 다양한 기준으로 제품을 구분하며, 총 200개의 고유 카테고리가 존재합니다. 이 컬럼을 활용하여 제품별 세부 분석 및 분류 정책 수립이 가능합니다.\n\n3. 데이터 특성 (NULL 허용 여부, 값 범위 등)  \nNULL 값은 허용되지 않으며(비율 0%), 문자열 값으로 최소 2자에서 최대 29자까지 분포합니다. 대표적인 값은 'Case', 'Air Conditioner', 'Cartridges' 등입니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명 (한 줄, 20자 이내)
# 제품 소분류 카테고리
#
# 2. 상세 설명 (2-3줄, 비즈니스 의미 포함)
# 내부 시스템에서 각 제품을 더욱 세분화하기 위해 관리하는 제품의 소분류 카테고리 코드 또는 이름입니다. 제품군 내에서 응용, 기능, 용도 등 다양한 기준으로 제품을 구분하며, 총 200개의 고유 카테고리가 존재합니다. 이 컬럼을 활용하여 제품별 세부 분석 및 분류 정책 수립이 가능합니다.
#
# 3. 데이터 특성 (NULL 허용 여부, 값 범위 등)
# NULL 값은 허용되지 않으며(비율 0%), 문자열 값으로 최소 2자에서 최대 29자까지 분포합니다. 대표적인 값은 'Case', 'Air Conditioner', 'Cartridges' 등입니다.'
# ✅ API 응답 수신 (길이: 374자)
#   - model_name 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 591자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: model_name
#     - 데이터 타입: object
#     - NULL 비율: 2.78%
#     - 고유값 개수: 2120
#     - 기존 설명: 제품의 공식 모델명입니다. 사용자가 일반적으로 인지하는 이름입니다. (예: Galaxy S24 Ul...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명 (20자 이내)  \n공식 제품 모델명 정보\n\n2. 상세 설명 (2-3줄)  \n제품의 공식 모델명을 나타내는 컬럼으로, 일반적으로 소비자나 판매자가 인식하는 제품명을 저장합니다. 예시로 'Galaxy S24 Ultra'와 같이 이름이 직관적으로 표기된 경우도 있지만, 제조사의 코드명(예: 'SM-S938N')이 포함될 수 있습니다. 비즈니스적으로 제품 식별 및 분류, 마케팅 자료 등 다양한 목적으로 활용됩니다.\n\n3. 데이터 특성  \n- 데이터 타입: 문자열(object)  \n- NULL 허용(약 2.78%): 일부 제품의 모델명이 미기입 또는 불명확  \n- 값 범위: 문자열 길이 1~18자, 평균 10.5자  \n- 고유값 개수: 2,120개  \n- 대표값: 'None'(77건, 결측 대체), 'SM-S938N'(25건), 'SM-F741N'(22건)  \n- 공식 모델명 및 코드명이 혼재되어 있음", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명 (20자 이내)
# 공식 제품 모델명 정보
#
# 2. 상세 설명 (2-3줄)
# 제품의 공식 모델명을 나타내는 컬럼으로, 일반적으로 소비자나 판매자가 인식하는 제품명을 저장합니다. 예시로 'Galaxy S24 Ultra'와 같이 이름이 직관적으로 표기된 경우도 있지만, 제조사의 코드명(예: 'SM-S938N')이 포함될 수 있습니다. 비즈니스적으로 제품 식별 및 분류, 마케팅 자료 등 다양한 목적으로 활용됩니다.
#
# 3. 데이터 특성
# - 데이터 타입: 문자열(object)
# - NULL 허용(약 2.78%): 일부 제품의 모델명이 미기입 또는 불명확
# - 값 범위: 문자열 길이 1~18자, 평균 10.5자
# - 고유값 개수: 2,120개
# - 대표값: 'None'(77건, 결측 대체), 'SM-S938N'(25건), 'SM-F741N'(22건)
# - 공식 모델명 및 코드명이 혼재되어 있음'
# ✅ API 응답 수신 (길이: 459자)
#   - model_code 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 609자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: model_code
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 2774
#     - 기존 설명: 제품의 세부 사양(색상, 용량 등)을 포함하는 고유 모델 코드입니다. (예: SM-S928NZ......
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n제품별 고유 모델 코드\n\n2. 상세 설명  \n각 제품의 세부 사양(색상, 용량 등)을 포함한 고유 모델 코드로, 제품을 정확히 식별하고 관리하기 위해 사용됩니다. 예를 들어, 'SM-S928NZ...'와 같이 제조사·시리즈·특성을 조합한 코드가 포함됩니다. 제품 라인업 내에서 사양에 따라 코드가 다르게 부여되어, 재고·판매·분석 시 중요한 기준값입니다.\n\n3. 데이터 특성  \n- NULL 허용 여부: 불허 (NULL 비율 0.00%)\n- 값 범위: 최소 5자 ~ 최대 18자, 평균 12.7자\n- 고유값: 2,774개로, 고유성이 높음 (중복 없음)\n- 대표값 예시: 'JBLQUANTUM300BLK', 'SM-X520NZAAKOO', 'SM-X620NLBEKOO'", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 제품별 고유 모델 코드
#
# 2. 상세 설명
# 각 제품의 세부 사양(색상, 용량 등)을 포함한 고유 모델 코드로, 제품을 정확히 식별하고 관리하기 위해 사용됩니다. 예를 들어, 'SM-S928NZ...'와 같이 제조사·시리즈·특성을 조합한 코드가 포함됩니다. 제품 라인업 내에서 사양에 따라 코드가 다르게 부여되어, 재고·판매·분석 시 중요한 기준값입니다.
#
# 3. 데이터 특성
# - NULL 허용 여부: 불허 (NULL 비율 0.00%)
# - 값 범위: 최소 5자 ~ 최대 18자, 평균 12.7자
# - 고유값: 2,774개로, 고유성이 높음 (중복 없음)
# - 대표값 예시: 'JBLQUANTUM300BLK', 'SM-X520NZAAKOO', 'SM-X620NLBEKOO''
# ✅ API 응답 수신 (길이: 385자)
#   - product_id 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 572자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: product_id
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 2774
#     - 기존 설명: 데이터베이스에서 각 제품을 식별하기 위한 고유 ID입니다.
#     - 문자열 길이 정보:
#      ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명 (20자 이내)  \n제품을 식별하는 고유 ID\n\n2. 상세 설명  \nproduct_id는 각 제품을 고유하게 식별하기 위해 사용되는 식별자입니다. 모든 제품에 고유하게 10자리의 문자열로 할당되어 데이터 중복을 방지하고, 제품 관련 정보의 조회 및 연계를 위해 활용됩니다. 업무 내 제품별 통계, 추적, 관리에 필수적인 역할을 합니다.\n\n3. 데이터 특성  \n- NULL 허용 여부: 허용하지 않음 (NULL 비율 0%)\n- 값 범위: 10자리의 문자열, 총 2,774개 고유값\n- 형태 예시: 'G000190421'\n- 중복 없음, 모든 값이 유일함", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명 (20자 이내)
# 제품을 식별하는 고유 ID
#
# 2. 상세 설명
# product_id는 각 제품을 고유하게 식별하기 위해 사용되는 식별자입니다. 모든 제품에 고유하게 10자리의 문자열로 할당되어 데이터 중복을 방지하고, 제품 관련 정보의 조회 및 연계를 위해 활용됩니다. 업무 내 제품별 통계, 추적, 관리에 필수적인 역할을 합니다.
#
# 3. 데이터 특성
# - NULL 허용 여부: 허용하지 않음 (NULL 비율 0%)
# - 값 범위: 10자리의 문자열, 총 2,774개 고유값
# - 형태 예시: 'G000190421'
# - 중복 없음, 모든 값이 유일함'
# ✅ API 응답 수신 (길이: 317자)
#   - product_name 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 619자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: product_name
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 1681
#     - 기존 설명: 웹사이트에 최종적으로 표시되는 제품명입니다. (예: 갤럭시 S24 Ultra 자급제 256GB ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명:  \n최종 웹사이트 제품명\n\n2. 상세 설명:  \n사용자에게 웹사이트에서 보여지는 제품의 공식 명칭을 나타내는 컬럼입니다. 예시로 '갤럭시 S24 Ultra 자급제 256GB 티타늄 그레이'와 같이 모델명, 사양 및 색상 정보가 포함되어 있습니다. 다양한 브랜드 및 모델 정보를 포괄하며, 제품 검색 및 노출에 활용됩니다.\n\n3. 데이터 특성:  \n- NULL 없음(0.00%, 반드시 값 존재)  \n- 데이터 타입: 문자열(object), 최소 3자~최대 120자, 평균 28.9자  \n- 총 1681개 고유값 존재  \n- 예: '갤럭시 링'(33개), '갤럭시 S25 울트라 자급제'(12개), 'Bespoke AI 냉장고 4도어 902L'(10개)", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명:
# 최종 웹사이트 제품명
#
# 2. 상세 설명:
# 사용자에게 웹사이트에서 보여지는 제품의 공식 명칭을 나타내는 컬럼입니다. 예시로 '갤럭시 S24 Ultra 자급제 256GB 티타늄 그레이'와 같이 모델명, 사양 및 색상 정보가 포함되어 있습니다. 다양한 브랜드 및 모델 정보를 포괄하며, 제품 검색 및 노출에 활용됩니다.
#
# 3. 데이터 특성:
# - NULL 없음(0.00%, 반드시 값 존재)
# - 데이터 타입: 문자열(object), 최소 3자~최대 120자, 평균 28.9자
# - 총 1681개 고유값 존재
# - 예: '갤럭시 링'(33개), '갤럭시 S25 울트라 자급제'(12개), 'Bespoke AI 냉장고 4도어 902L'(10개)'
# ✅ API 응답 수신 (길이: 374자)
#
# 배치 처리: 11-15/34
#   - product_color 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 557자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: product_color
#     - 데이터 타입: object
#     - NULL 비율: 15.07%
#     - 고유값 개수: 241
#     - 기존 설명: 제품의 색상명입니다. (예: 티타늄 블랙, 코튼 화이트)
#     - 문자열 길이 정보:
#    ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n제품의 색상명을 저장하는 컬럼\n\n2. 상세 설명  \nproduct_color 컬럼은 KT 제품의 색상명을 나타내며, 판매 및 재고 관리, 마케팅 등 다양한 비즈니스 의사결정에 활용됩니다. 색상은 '블랙', '화이트', '티타늄 블랙' 등 총 241종이 입력되며, 일부 제품은 색상 정보가 존재하지 않을 수 있습니다.\n\n3. 데이터 특성  \n- 데이터 타입: 문자열(object)\n- NULL 허용: 약 15.07%의 값이 결측(NULL 또는 'None')  \n- 값 범위: 최소 1자, 최대 37자, 평균 4.2자로 이루어진 241개의 고유 색상명  \n- 주요 값: '블랙', '화이트', '티타늄 블랙' 등", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 제품의 색상명을 저장하는 컬럼
#
# 2. 상세 설명
# product_color 컬럼은 KT 제품의 색상명을 나타내며, 판매 및 재고 관리, 마케팅 등 다양한 비즈니스 의사결정에 활용됩니다. 색상은 '블랙', '화이트', '티타늄 블랙' 등 총 241종이 입력되며, 일부 제품은 색상 정보가 존재하지 않을 수 있습니다.
#
# 3. 데이터 특성
# - 데이터 타입: 문자열(object)
# - NULL 허용: 약 15.07%의 값이 결측(NULL 또는 'None')
# - 값 범위: 최소 1자, 최대 37자, 평균 4.2자로 이루어진 241개의 고유 색상명
# - 주요 값: '블랙', '화이트', '티타늄 블랙' 등'
# ✅ API 응답 수신 (길이: 351자)
#   - release_date 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 560자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: release_date
#     - 데이터 타입: object
#     - NULL 비율: 1.37%
#     - 고유값 개수: 96
#     - 기존 설명: 제품의 공식 출시일입니다.
#     - 문자열 길이 정보:
#       - 최소 길이: 10.0
#    ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n제품의 공식 출시일(YYYY-MM-DD)\n\n2. 상세 설명  \nrelease_date 컬럼은 해당 제품의 시장 공식 출시 날짜를 나타냅니다. 이 정보는 제품의 유통 시작 시점이나 상품 활성화 일정을 파악하는 데 활용됩니다. 대부분의 값은 'YYYY-MM-DD' 형식이며, 향후 제품 라인업 일정 관리 및 판매 분석에 중요한 기준이 됩니다.\n\n3. 데이터 특성  \nNULL 값이 일부(약 1.37%) 존재할 수 있으며, 값은 날짜형 문자열(10자리, 'YYYY-MM-DD')로 입력됩니다. 고유 날짜는 총 96개이며, 출시일이 특정 월(2025-01~07)에 집중되어 나타나는 경향이 있습니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 제품의 공식 출시일(YYYY-MM-DD)
#
# 2. 상세 설명
# release_date 컬럼은 해당 제품의 시장 공식 출시 날짜를 나타냅니다. 이 정보는 제품의 유통 시작 시점이나 상품 활성화 일정을 파악하는 데 활용됩니다. 대부분의 값은 'YYYY-MM-DD' 형식이며, 향후 제품 라인업 일정 관리 및 판매 분석에 중요한 기준이 됩니다.
#
# 3. 데이터 특성
# NULL 값이 일부(약 1.37%) 존재할 수 있으며, 값은 날짜형 문자열(10자리, 'YYYY-MM-DD')로 입력됩니다. 고유 날짜는 총 96개이며, 출시일이 특정 월(2025-01~07)에 집중되어 나타나는 경향이 있습니다.'
# ✅ API 응답 수신 (길이: 342자)
#   - is_ai_subscription_eligible 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 569자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: is_ai_subscription_eligible
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 2
#     - 기존 설명: Galaxy AI와 같은 AI 관련 구독 서비스 가입 가능 여부를 나타냅니...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \nAI 구독 서비스 가입 가능 여부\n\n2. 상세 설명  \n해당 상품이 Galaxy AI 등 AI 관련 구독 서비스를 이용할 수 있는지 여부를 나타냅니다. 'Y'는 가입 가능, 'N'은 가입 불가를 의미합니다. 비즈니스적으로, 특정 상품의 AI 서비스 구매 가능성을 판별하거나 프로모션 대상 선정에 활용할 수 있습니다.\n\n3. 데이터 특성  \nNULL 값 없이 모두 값이 존재하며, 값은 'Y'(가능)와 'N'(불가) 두 가지로만 구성되어 있습니다.  \n- 값 범위: {'Y', 'N'}\n- NULL 허용: 불가 (0.00%)  \n가장 흔한 값은 'N'입니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# AI 구독 서비스 가입 가능 여부
#
# 2. 상세 설명
# 해당 상품이 Galaxy AI 등 AI 관련 구독 서비스를 이용할 수 있는지 여부를 나타냅니다. 'Y'는 가입 가능, 'N'은 가입 불가를 의미합니다. 비즈니스적으로, 특정 상품의 AI 서비스 구매 가능성을 판별하거나 프로모션 대상 선정에 활용할 수 있습니다.
#
# 3. 데이터 특성
# NULL 값 없이 모두 값이 존재하며, 값은 'Y'(가능)와 'N'(불가) 두 가지로만 구성되어 있습니다.
# - 값 범위: {'Y', 'N'}
# - NULL 허용: 불가 (0.00%)
# 가장 흔한 값은 'N'입니다.'
# ✅ API 응답 수신 (길이: 322자)
#   - is_smart_subscription_eligible 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 589자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: is_smart_subscription_eligible
#     - 데이터 타입: object
#     - NULL 비율: 93.76%
#     - 고유값 개수: 3
#     - 기존 설명: 스마트 기기 구독 서비스(삼성닷컴 구독) 가입 가능 여부를 나타냅니...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n스마트 구독 서비스 가입 가능 여부\n\n2. 상세 설명  \n해당 상품이 삼성닷컴 스마트 기기 구독 서비스(스마트 서브스크립션)에 가입할 수 있는지의 여부를 나타냅니다. 값이 'Y'이면 구독 서비스 가입이 가능하며, 'N'이면 불가능합니다. 비즈니스에서는 서비스 대상 상품 선별 및 마케팅, 제휴 정책 수립 등에 활용됩니다.\n\n3. 데이터 특성  \n- 데이터 타입: object  \n- 값 범위: 'Y'(가입 가능), 'N'(가입 불가), 'None'(정보 없음/미정)  \n- NULL(정보 없음) 허용: 약 93.76%의 행이 'None'으로 처리되어 있음  \n- 고유값: 3개 ('Y', 'N', 'None')  \n- 모든 값의 길이는 1자입니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 스마트 구독 서비스 가입 가능 여부
#
# 2. 상세 설명
# 해당 상품이 삼성닷컴 스마트 기기 구독 서비스(스마트 서브스크립션)에 가입할 수 있는지의 여부를 나타냅니다. 값이 'Y'이면 구독 서비스 가입이 가능하며, 'N'이면 불가능합니다. 비즈니스에서는 서비스 대상 상품 선별 및 마케팅, 제휴 정책 수립 등에 활용됩니다.
#
# 3. 데이터 특성
# - 데이터 타입: object
# - 값 범위: 'Y'(가입 가능), 'N'(가입 불가), 'None'(정보 없음/미정)
# - NULL(정보 없음) 허용: 약 93.76%의 행이 'None'으로 처리되어 있음
# - 고유값: 3개 ('Y', 'N', 'None')
# - 모든 값의 길이는 1자입니다.'
# ✅ API 응답 수신 (길이: 373자)
#   - is_galaxy_club_eligible 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 557자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: is_galaxy_club_eligible
#     - 데이터 타입: object
#     - NULL 비율: 98.34%
#     - 고유값 개수: 2
#     - 기존 설명: 갤럭시 클럽 가입 또는 혜택 적용 가능 여부를 나타냅니다. (True/False...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n갤럭시 클럽 혜택 가능 여부\n\n2. 상세 설명  \n해당 상품이 갤럭시 클럽 서비스(가입 및 혜택 적용)에 적합한지를 나타내는 컬럼입니다. 'N'은 혜택 적용 불가를 의미하며, 대부분의 상품에 대해 정보가 기입되지 않아 미확인 상태입니다. 비즈니스적으로 갤럭시 클럽 대상 상품 판별 및 집계에 활용됩니다.\n\n3. 데이터 특성  \nNULL(미기입) 값이 98% 이상(2728/2774건)으로 대부분 정보가 없으며, 값은 'N'(혜택 불가) 또는 NULL만 존재합니다. True/False가 아닌 'N' 값만 확인됨에 따라 실제 혜택 가능 상품은 데이터상 미기록 상태입니다. NULL 허용 컬럼입니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 갤럭시 클럽 혜택 가능 여부
#
# 2. 상세 설명
# 해당 상품이 갤럭시 클럽 서비스(가입 및 혜택 적용)에 적합한지를 나타내는 컬럼입니다. 'N'은 혜택 적용 불가를 의미하며, 대부분의 상품에 대해 정보가 기입되지 않아 미확인 상태입니다. 비즈니스적으로 갤럭시 클럽 대상 상품 판별 및 집계에 활용됩니다.
#
# 3. 데이터 특성
# NULL(미기입) 값이 98% 이상(2728/2774건)으로 대부분 정보가 없으며, 값은 'N'(혜택 불가) 또는 NULL만 존재합니다. True/False가 아닌 'N' 값만 확인됨에 따라 실제 혜택 가능 상품은 데이터상 미기록 상태입니다. NULL 허용 컬럼입니다.'
# ✅ API 응답 수신 (길이: 344자)
#
# 배치 처리: 16-20/34
#   - is_installment_payment_available 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 550자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: is_installment_payment_available
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 2
#     - 기존 설명: 할부 결제 가능 여부를 나타냅니다. (True/False)
#    ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n할부 결제 가능 여부(Y/N) 표시\n\n2. 상세 설명  \n해당 상품이 할부 결제로 구매 가능한지를 나타내는 컬럼입니다. 'Y'는 할부가 가능함을, 'N'은 불가능함을 뜻하며, 결제 옵션 안내 및 마케팅 전략 수립 등에 활용됩니다.\n\n3. 데이터 특성  \nNULL 값 없이 모두 기입되어 있으며, 값은 'Y' 또는 'N'만 존재합니다. ('Y': 2208개, 'N': 566개)", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 할부 결제 가능 여부(Y/N) 표시
#
# 2. 상세 설명
# 해당 상품이 할부 결제로 구매 가능한지를 나타내는 컬럼입니다. 'Y'는 할부가 가능함을, 'N'은 불가능함을 뜻하며, 결제 옵션 안내 및 마케팅 전략 수립 등에 활용됩니다.
#
# 3. 데이터 특성
# NULL 값 없이 모두 기입되어 있으며, 값은 'Y' 또는 'N'만 존재합니다. ('Y': 2208개, 'N': 566개)'
# ✅ API 응답 수신 (길이: 221자)
#   - product_detail_url 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 648자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: product_detail_url
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 2774
#     - 기존 설명: 제품의 상세 페이지로 연결되는 전체 URL 주소입니다.
#     - 문자열 길이 정보:...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. 짧은 설명 (한 줄, 20자 이내)  \n제품 상세정보 URL\n\n2. 상세 설명 (2-3줄, 비즈니스 의미 포함)  \nproduct_detail_url 컬럼은 각 제품의 공식 상세 페이지로 연결되는 전체 URL을 저장합니다. 이를 통해 사용자는 제품별로 세부 정보, 사양, 이미지 등을 직접 확인할 수 있습니다. 마케팅, 고객 지원, 상품 추천 등 다양한 비즈니스 프로세스에서 활용됩니다.\n\n3. 데이터 특성 (NULL 허용 여부, 값 범위 등)  \nNULL 값 없이 모든 제품에 대해 값이 존재하며(0.00%), 고유값은 2,774개로 각 제품별 개별 URL로 구성됩니다. URL 길이는 최소 53자, 최대 138자이며, 평균 약 83.1자입니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명 (한 줄, 20자 이내)
# 제품 상세정보 URL
#
# 2. 상세 설명 (2-3줄, 비즈니스 의미 포함)
# product_detail_url 컬럼은 각 제품의 공식 상세 페이지로 연결되는 전체 URL을 저장합니다. 이를 통해 사용자는 제품별로 세부 정보, 사양, 이미지 등을 직접 확인할 수 있습니다. 마케팅, 고객 지원, 상품 추천 등 다양한 비즈니스 프로세스에서 활용됩니다.
#
# 3. 데이터 특성 (NULL 허용 여부, 값 범위 등)
# NULL 값 없이 모든 제품에 대해 값이 존재하며(0.00%), 고유값은 2,774개로 각 제품별 개별 URL로 구성됩니다. URL 길이는 최소 53자, 최대 138자이며, 평균 약 83.1자입니다.'
# ✅ API 응답 수신 (길이: 365자)
#   - channel_code 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 488자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: channel_code
#     - 데이터 타입: object
#     - NULL 비율: 100.00%
#     - 고유값 개수: 1
#     - 기존 설명: 판매 채널을 구분하는 코드입니다. (예: 온라인, B2B, 특정 프로모션)
#     - 문자열 길이...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. 짧은 설명  \n판매 채널 구분 코드\n\n2. 상세 설명  \n상품의 판매가 이루어진 채널(예: 온라인, B2B, 특정 프로모션 등)을 식별하기 위한 코드입니다. 비즈니스에서 다양한 판매 경로별로 실적을 집계하거나 전략을 수립할 때 활용됩니다. 해당 컬럼은 향후 여러 채널이 통합된 데이터 관리와 분석 목적으로 사용될 수 있습니다.\n\n3. 데이터 특성  \n현재 모든 값이 NULL(100%)이며, 실제 데이터가 입력되지 않은 상태입니다. 값의 범위는 정의된 판매 채널 코드(예: 온라인, B2B 등)로 제한될 예정입니다. 향후 사용 시 NON-NULL 값 입력을 권장합니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 판매 채널 구분 코드
#
# 2. 상세 설명
# 상품의 판매가 이루어진 채널(예: 온라인, B2B, 특정 프로모션 등)을 식별하기 위한 코드입니다. 비즈니스에서 다양한 판매 경로별로 실적을 집계하거나 전략을 수립할 때 활용됩니다. 해당 컬럼은 향후 여러 채널이 통합된 데이터 관리와 분석 목적으로 사용될 수 있습니다.
#
# 3. 데이터 특성
# 현재 모든 값이 NULL(100%)이며, 실제 데이터가 입력되지 않은 상태입니다. 값의 범위는 정의된 판매 채널 코드(예: 온라인, B2B 등)로 제한될 예정입니다. 향후 사용 시 NON-NULL 값 입력을 권장합니다.'
# ✅ API 응답 수신 (길이: 321자)
#   - unique_selling_point 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 651자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: unique_selling_point
#     - 데이터 타입: object
#     - NULL 비율: 3.89%
#     - 고유값 개수: 880
#     - 기존 설명: 제품의 핵심 특장점을 요약한 문구 모음입니다. (예: 'Galaxy AI 탑재', ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n제품의 주요 특장점 요약 문구\n\n2. 상세 설명  \nunique_selling_point 컬럼은 각 제품의 핵심적인 판매 포인트 또는 차별화된 특징을 요약하여 담은 문구입니다. 예를 들어 'Galaxy AI 탑재', '2억 화소 카메라'와 같이 제품이 시장에서 어필하고자 하는 주요 가치 또는 기술적 장점을 구체적으로 설명합니다. 마케팅 및 상품 기획에서 제품별 장점 파악, 비교, 검색 필터링에 활용될 수 있습니다.\n\n3. 데이터 특성  \nNULL 허용(약 3.9%)되며, 문자열(최대 160자) 형태로 여러 특장점이 쉼표 또는 배열 형태로 기록되는 사례가 있습니다. 고유값 종류는 880개로 다양하며, 값은 2자에서 160자까지 분포합니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 제품의 주요 특장점 요약 문구
#
# 2. 상세 설명
# unique_selling_point 컬럼은 각 제품의 핵심적인 판매 포인트 또는 차별화된 특징을 요약하여 담은 문구입니다. 예를 들어 'Galaxy AI 탑재', '2억 화소 카메라'와 같이 제품이 시장에서 어필하고자 하는 주요 가치 또는 기술적 장점을 구체적으로 설명합니다. 마케팅 및 상품 기획에서 제품별 장점 파악, 비교, 검색 필터링에 활용될 수 있습니다.
#
# 3. 데이터 특성
# NULL 허용(약 3.9%)되며, 문자열(최대 160자) 형태로 여러 특장점이 쉼표 또는 배열 형태로 기록되는 사례가 있습니다. 고유값 종류는 880개로 다양하며, 값은 2자에서 160자까지 분포합니다.'
# ✅ API 응답 수신 (길이: 371자)
#   - review_count 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 506자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: review_count
#     - 데이터 타입: float64
#     - NULL 비율: 2.45%
#     - 고유값 개수: 246
#     - 기존 설명: 해당 제품에 달린 리뷰의 총 개수입니다.
#     - 통계 정보:
#       - 최소값: 0.0
# ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. 짧은 설명  \n해당 제품의 총 리뷰 개수\n\n2. 상세 설명  \n각 제품에 고객이 남긴 리뷰의 총 개수를 나타냅니다. 리뷰 수는 제품의 인기도나 고객 참여도를 파악하는 데 활용될 수 있습니다. 이 값이 높을수록 해당 제품에 대한 사용자 관심이 많음을 의미합니다.\n\n3. 데이터 특성  \n- NULL 허용: 가능 (2.45% NULL)\n- 값 범위: 0~8,464 (실수형)\n- 평균: 약 442개, 중앙값: 20개\n- 고유값: 246개  \n- 일부 제품은 리뷰가 없거나(0 또는 NULL), 매우 많은 리뷰가 존재합니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 해당 제품의 총 리뷰 개수
#
# 2. 상세 설명
# 각 제품에 고객이 남긴 리뷰의 총 개수를 나타냅니다. 리뷰 수는 제품의 인기도나 고객 참여도를 파악하는 데 활용될 수 있습니다. 이 값이 높을수록 해당 제품에 대한 사용자 관심이 많음을 의미합니다.
#
# 3. 데이터 특성
# - NULL 허용: 가능 (2.45% NULL)
# - 값 범위: 0~8,464 (실수형)
# - 평균: 약 442개, 중앙값: 20개
# - 고유값: 246개
# - 일부 제품은 리뷰가 없거나(0 또는 NULL), 매우 많은 리뷰가 존재합니다.'
# ✅ API 응답 수신 (길이: 293자)
#
# 배치 처리: 21-25/34
#   - review_rating_score 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 510자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: review_rating_score
#     - 데이터 타입: float64
#     - NULL 비율: 2.45%
#     - 고유값 개수: 122
#     - 기존 설명: 해당 제품의 평균 리뷰 별점입니다. (예: 4.8)
#     - 통계 정보:
#     ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. 짧은 설명 (한 줄, 20자 이내)  \n제품 평균 리뷰 평점\n\n2. 상세 설명 (2-3줄, 비즈니스 의미 포함)  \n이 컬럼은 해당 제품에 대해 고객들이 남긴 리뷰의 평균 별점을 0.0~5.0 사이 값으로 나타냅니다. 평점이 높을수록 고객 만족도가 높음을 의미하며, 마케팅 및 제품 개선을 위한 지표로 활용할 수 있습니다. 일부 제품의 경우 리뷰가 없어 값이 누락될 수 있습니다.\n\n3. 데이터 특성 (NULL 허용 여부, 값 범위 등)  \n- NULL 허용: O (2.45% NULL, 리뷰 없는 경우)  \n- 값 범위: 0.0 ~ 5.0 (float64)  \n- 고유값 개수: 122  \n- 대표 통계: 평균 3.72, 중앙값 4.67, 표준편차 1.90', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명 (한 줄, 20자 이내)
# 제품 평균 리뷰 평점
#
# 2. 상세 설명 (2-3줄, 비즈니스 의미 포함)
# 이 컬럼은 해당 제품에 대해 고객들이 남긴 리뷰의 평균 별점을 0.0~5.0 사이 값으로 나타냅니다. 평점이 높을수록 고객 만족도가 높음을 의미하며, 마케팅 및 제품 개선을 위한 지표로 활용할 수 있습니다. 일부 제품의 경우 리뷰가 없어 값이 누락될 수 있습니다.
#
# 3. 데이터 특성 (NULL 허용 여부, 값 범위 등)
# - NULL 허용: O (2.45% NULL, 리뷰 없는 경우)
# - 값 범위: 0.0 ~ 5.0 (float64)
# - 고유값 개수: 122
# - 대표 통계: 평균 3.72, 중앙값 4.67, 표준편차 1.90'
# ✅ API 응답 수신 (길이: 371자)
#   - standard_price 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 526자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: standard_price
#     - 데이터 타입: float64
#     - NULL 비율: 0.00%
#     - 고유값 개수: 968
#     - 기존 설명: 할인이 적용되지 않은 정상 판매가입니다.
#     - 통계 정보:
#       - 최소값: 33...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. 짧은 설명  \n정상 판매 기준 가격\n\n2. 상세 설명  \n할인이나 프로모션 적용 전의 제품 정상 판매가를 나타냅니다. 모든 제품의 기본 가격으로, 판매 정책 또는 가격 책정 분석 시 기준점이 됩니다. 비즈니스적으로는 회사의 수익 예측 및 원가 관리에 활용됩니다.\n\n3. 데이터 특성  \nNULL 허용: 불가 (NULL 값 없음)  \n값 범위: 3,300 ~ 52,690,000  \n평균: 1,890,617.43  \n중앙값: 676,500.00  \n특이사항: 제품별로 다양한 가격 분포를 보임 (표준편차 3,490,187.38)', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 정상 판매 기준 가격
#
# 2. 상세 설명
# 할인이나 프로모션 적용 전의 제품 정상 판매가를 나타냅니다. 모든 제품의 기본 가격으로, 판매 정책 또는 가격 책정 분석 시 기준점이 됩니다. 비즈니스적으로는 회사의 수익 예측 및 원가 관리에 활용됩니다.
#
# 3. 데이터 특성
# NULL 허용: 불가 (NULL 값 없음)
# 값 범위: 3,300 ~ 52,690,000
# 평균: 1,890,617.43
# 중앙값: 676,500.00
# 특이사항: 제품별로 다양한 가격 분포를 보임 (표준편차 3,490,187.38)'
# ✅ API 응답 수신 (길이: 297자)
#   - member_price 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 525자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: member_price
#     - 데이터 타입: float64
#     - NULL 비율: 0.00%
#     - 고유값 개수: 966
#     - 기존 설명: 삼성닷컴 회원에게만 적용되는 할인가입니다.
#     - 통계 정보:
#       - 최소값: 330...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. 짧은 설명  \n삼성닷컴 회원 전용 할인가\n\n2. 상세 설명  \n이 컬럼은 삼성닷컴 회원에게만 제공되는 상품의 할인가를 나타냅니다. 각 상품마다 적용되는 회원 할인 가격이 다르며, 이를 통해 회원 대상의 맞춤 혜택 및 가격 정책 분석이 가능합니다. 비회원과 구분되는 특별가로 사용됩니다.\n\n3. 데이터 특성  \nNULL 값은 존재하지 않으며(0%), 값 범위는 3,300원에서 52,690,000원까지로 상품 종류에 따라 다양합니다. 총 966개의 서로 다른 가격이 존재하며, 평균 가격은 약 1,890,277원, 중앙값은 676,500원, 표준편차는 3,490,346.28입니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 삼성닷컴 회원 전용 할인가
#
# 2. 상세 설명
# 이 컬럼은 삼성닷컴 회원에게만 제공되는 상품의 할인가를 나타냅니다. 각 상품마다 적용되는 회원 할인 가격이 다르며, 이를 통해 회원 대상의 맞춤 혜택 및 가격 정책 분석이 가능합니다. 비회원과 구분되는 특별가로 사용됩니다.
#
# 3. 데이터 특성
# NULL 값은 존재하지 않으며(0%), 값 범위는 3,300원에서 52,690,000원까지로 상품 종류에 따라 다양합니다. 총 966개의 서로 다른 가격이 존재하며, 평균 가격은 약 1,890,277원, 중앙값은 676,500원, 표준편차는 3,490,346.28입니다.'
# ✅ API 응답 수신 (길이: 327자)
#   - benefit_price 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 550자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: benefit_price
#     - 데이터 타입: float64
#     - NULL 비율: 38.21%
#     - 고유값 개수: 699
#     - 기존 설명: 즉시 할인, 쿠폰 등 모든 혜택이 적용된 최종 가격으로, '혜택가'에 해당합니다.
#     -...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. 짧은 설명  \n모든 혜택 적용 후 최종가\n\n2. 상세 설명  \nbenefit_price는 상품에 즉시 할인, 쿠폰 등 모든 프로모션 혜택이 적용된 후의 최종 판매 가격(혜택가)을 의미합니다. 이 값은 소비자가 실제로 결제하는 금액을 나타내며, 마케팅·판매 분석에서 실질적인 구매가격 지표로 활용됩니다.\n\n3. 데이터 특성  \n- 데이터 타입: float64  \n- NULL 허용(38.21%), 일부 상품은 혜택가가 미적용  \n- 값 범위: 3,000 ~ 50,700,000  \n- 평균: 약 2,177,148  \n- 중앙값: 1,390,000  \n- 고유값 개수: 699  \n- 가격 변동성이 큼(표준편차: 약 3,172,409)', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 모든 혜택 적용 후 최종가
#
# 2. 상세 설명
# benefit_price는 상품에 즉시 할인, 쿠폰 등 모든 프로모션 혜택이 적용된 후의 최종 판매 가격(혜택가)을 의미합니다. 이 값은 소비자가 실제로 결제하는 금액을 나타내며, 마케팅·판매 분석에서 실질적인 구매가격 지표로 활용됩니다.
#
# 3. 데이터 특성
# - 데이터 타입: float64
# - NULL 허용(38.21%), 일부 상품은 혜택가가 미적용
# - 값 범위: 3,000 ~ 50,700,000
# - 평균: 약 2,177,148
# - 중앙값: 1,390,000
# - 고유값 개수: 699
# - 가격 변동성이 큼(표준편차: 약 3,172,409)'
# ✅ API 응답 수신 (길이: 356자)
#   - review_text_collection 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 628자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: review_text_collection
#     - 데이터 타입: object
#     - NULL 비율: 36.66%
#     - 고유값 개수: 1750
#     - 기존 설명: 사용자들이 작성한 리뷰 텍스트 데이터의 모음입니다.
#     - 문자열 길이 ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. 짧은 설명   \n상품별 사용자 리뷰 텍스트 모음\n\n2. 상세 설명  \n본 컬럼은 각 상품에 대해 사용자들이 남긴 리뷰 텍스트를 리스트 형태로 저장한 필드입니다. 다양한 사용 경험, 만족도, 개선 요청 등 고객의 생생한 의견을 담고 있어 상품의 품질 평가 및 서비스 개선에 중요한 인사이트를 제공합니다.  \n최소 1개~최대 수천 글자의 다양한 리뷰가 포함될 수 있습니다.\n\n3. 데이터 특성  \n- NULL(결측치) 허용: O (약 36.66% 결측)  \n- 데이터 타입: object (주로 리스트 형태의 문자열)  \n- 값 범위: 최소 4자, 최대 14,285자, 평균 2,088.8자  \n- 리뷰가 없는 경우 ‘None’ 또는 NULL로 표시됨.  \n- 고유값 1,750개.  \n', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 상품별 사용자 리뷰 텍스트 모음
#
# 2. 상세 설명
# 본 컬럼은 각 상품에 대해 사용자들이 남긴 리뷰 텍스트를 리스트 형태로 저장한 필드입니다. 다양한 사용 경험, 만족도, 개선 요청 등 고객의 생생한 의견을 담고 있어 상품의 품질 평가 및 서비스 개선에 중요한 인사이트를 제공합니다.
# 최소 1개~최대 수천 글자의 다양한 리뷰가 포함될 수 있습니다.
#
# 3. 데이터 특성
# - NULL(결측치) 허용: O (약 36.66% 결측)
# - 데이터 타입: object (주로 리스트 형태의 문자열)
# ...
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 번들 상품 구성품 모델 코드
#
# 2. 상세 설명
# 이 컬럼은 번들(패키지) 상품의 경우, 해당 상품을 구성하는 각 구성품의 모델 코드들을 목록 형태로 제공합니다. 단일 상품의 경우에는 값이 NULL로 표시되며, 각 모델 코드는 쉼표로 구분되어 저장되어 있습니다. 이를 통해 각 번들 상품의 구성 내역을 빠르게 파악할 수 있습니다.
#
# 3. 데이터 특성
# - NULL 허용: 약 87.56%의 행에서 NULL 값이 존재하며, 이는 대부분 단일 상품임을 의미합니다.
# - 값 형태: 모델 코드 목록이 중괄호({})로 감싸져 있으며, 쉼표로 구분된 코드들이 포함됩니다.
# - 길이: 최소 11자, 최대 145자, 평균 46.5자
# - 유효값 개수: 총 346개의 고유 목록
# - 대표값: 단일 상품 또는 번들이 없는 경우 'None'이 가장 많음'
# ✅ API 응답 수신 (길이: 429자)
#
# 배치 처리: 31-34/34
#   - site_code 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 520자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: site_code
#     - 데이터 타입: object
#     - NULL 비율: 0.00%
#     - 고유값 개수: 1
#     - 기존 설명: 해당 상품이 판매되는 판매 채널에 대한 코드입니다. (예: B2C, FN)
#     - 문자열 길이 정보:
# ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n판매 채널을 표시하는 코드입니다.\n\n2. 상세 설명  \nsite_code 컬럼은 상품이 어떤 판매 채널(B2C 등)을 통해 판매되는지를 나타내는 고유 코드입니다. 현재 모든 데이터에 'B2C' 값만 존재하며, 향후 다양한 유통 채널 식별에 활용될 수 있습니다. 비즈니스에서는 이 값을 기반으로 채널별 집계 또는 통계를 낼 수 있습니다.\n\n3. 데이터 특성  \nNULL 값이 허용되지 않으며, 실제 데이터는 'B2C'로 단일 값(3자리 코드)만 존재합니다. 활용 시 코드값의 추가 또는 변경 가능성을 고려해야 합니다.", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 판매 채널을 표시하는 코드입니다.
#
# 2. 상세 설명
# site_code 컬럼은 상품이 어떤 판매 채널(B2C 등)을 통해 판매되는지를 나타내는 고유 코드입니다. 현재 모든 데이터에 'B2C' 값만 존재하며, 향후 다양한 유통 채널 식별에 활용될 수 있습니다. 비즈니스에서는 이 값을 기반으로 채널별 집계 또는 통계를 낼 수 있습니다.
#
# 3. 데이터 특성
# NULL 값이 허용되지 않으며, 실제 데이터는 'B2C'로 단일 값(3자리 코드)만 존재합니다. 활용 시 코드값의 추가 또는 변경 가능성을 고려해야 합니다.'
# ✅ API 응답 수신 (길이: 299자)
#   - final_price 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 544자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: final_price
#     - 데이터 타입: float64
#     - NULL 비율: 0.00%
#     - 고유값 개수: 933
#     - 기존 설명: 모든 할인, 쿠폰, 카드사 혜택 등이 최종 반영된 실제 결제 예상 금액입니다.
#     - 통계 정...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. 짧은 설명  \n최종 결제 예상 금액\n\n2. 상세 설명  \nfinal_price는 상품 구매 시 모든 할인, 쿠폰, 카드사 혜택 등이 적용된 후, 고객이 실제로 결제할 것으로 예상되는 최종 금액을 의미합니다. 비즈니스 관점에서 이는 판매 시점의 실질 매출과 고객 부담 금액 산정에 활용됩니다.\n\n3. 데이터 특성  \nNULL 값 없이 모든 레코드가 값을 가지며, 값은 최소 3,000원에서 최대 50,700,000원까지 분포합니다. 평균값은 약 1,523,102원, 중앙값은 569,750원으로 가격 분포가 다양하게 형성되어 있습니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 최종 결제 예상 금액
#
# 2. 상세 설명
# final_price는 상품 구매 시 모든 할인, 쿠폰, 카드사 혜택 등이 적용된 후, 고객이 실제로 결제할 것으로 예상되는 최종 금액을 의미합니다. 비즈니스 관점에서 이는 판매 시점의 실질 매출과 고객 부담 금액 산정에 활용됩니다.
#
# 3. 데이터 특성
# NULL 값 없이 모든 레코드가 값을 가지며, 값은 최소 3,000원에서 최대 50,700,000원까지 분포합니다. 평균값은 약 1,523,102원, 중앙값은 569,750원으로 가격 분포가 다양하게 형성되어 있습니다.'
# ✅ API 응답 수신 (길이: 301자)
#   - is_bispokle_goods 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 477자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: is_bispokle_goods
#     - 데이터 타입: object
#     - NULL 비율: 100.00%
#     - 고유값 개수: 1
#     - 기존 설명: 해당 제품의 비스포크 상품 여부를 나타냅니다.
#     - 문자열 길이 정보:
#       ...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n비스포크 상품 여부 표시\n\n2. 상세 설명  \n해당 컬럼은 제품이 비스포크(맞춤 제작) 상품인지 여부를 나타냅니다. 비스포크 상품 여부를 관리하여 맞춤형 제품의 분류 및 통계 집계에 활용할 수 있습니다. 현재 데이터에서는 값이 모두 NULL로, 실제 비스포크 상품 관련 정보가 입력되지 않은 상태입니다.\n\n3. 데이터 특성  \n- NULL 허용: 예 (현재 100% NULL)  \n- 값 범위: 비스포크 상품이면 'Y', 아니면 'N' 등으로 표시될 수 있음  \n- 데이터 타입: object(문자형)  \n- 현재는 모든 값이 NULL로 비스포크 여부가 입력되어 있지 않음", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 비스포크 상품 여부 표시
#
# 2. 상세 설명
# 해당 컬럼은 제품이 비스포크(맞춤 제작) 상품인지 여부를 나타냅니다. 비스포크 상품 여부를 관리하여 맞춤형 제품의 분류 및 통계 집계에 활용할 수 있습니다. 현재 데이터에서는 값이 모두 NULL로, 실제 비스포크 상품 관련 정보가 입력되지 않은 상태입니다.
#
# 3. 데이터 특성
# - NULL 허용: 예 (현재 100% NULL)
# - 값 범위: 비스포크 상품이면 'Y', 아니면 'N' 등으로 표시될 수 있음
# - 데이터 타입: object(문자형)
# - 현재는 모든 값이 NULL로 비스포크 여부가 입력되어 있지 않음'
# ✅ API 응답 수신 (길이: 331자)
#   - is_bundle_product 처리 중...
#
# 📝 API 요청 정보:
#   - 모델: gpt-4.1
#   - 엔드포인트: https://kt-azure-openai-dev-donghunseo.openai.azur...
#   - 프롬프트 길이: 530자
#   - 프롬프트 처음 200자:
#
#     테이블명: kt_merged_product_20250929
#     컬럼 정보:
#     - 컬럼명: is_bundle_product
#     - 데이터 타입: object
#     - NULL 비율: 87.56%
#     - 고유값 개수: 2
#     - 기존 설명: 해당 제품의 번들 상품 여부를 나타냅니다.
#     - 문자열 길이 정보:
#       - 최...
#
# 📋 응답 객체 타입: <class 'openai.types.chat.chat_completion.ChatCompletion'>
#   - choices 개수: 1
#   - choice 객체: Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="1. 짧은 설명  \n해당 상품이 번들 여부(Y/N)\n\n2. 상세 설명  \n'is_bundle_product' 컬럼은 해당 제품이 번들 상품(여러 제품이 묶여 제공되는 상품)인지를 구분하는 값입니다. 번들인 경우 'Y'로 표시되며, 번들 상품에 대한 다양한 프로모션 및 관리가 필요할 수 있습니다. NULL 값은 번들 여부가 정의되지 않은 경우로, 데이터 정합성 확보 시 주의가 필요합니다.\n\n3. 데이터 특성  \n- 허용 값: 'Y'(번들 상품), NULL(번들 여부 미정)\n- NULL 허용: 약 87.56% (대부분이 번들 여부 미정)\n- 문자열 길이: 1자리\n- 고유값 : 2개 ('Y', NULL)  \n- 비즈니스 시나리오에서 번들 상품의 식별에 활용됨", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None), content_filter_results={'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}})
#   - finish_reason: stop
#   - message 타입: <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
#   - content 타입: <class 'str'>
#   - content 값: '1. 짧은 설명
# 해당 상품이 번들 여부(Y/N)
#
# 2. 상세 설명
# 'is_bundle_product' 컬럼은 해당 제품이 번들 상품(여러 제품이 묶여 제공되는 상품)인지를 구분하는 값입니다. 번들인 경우 'Y'로 표시되며, 번들 상품에 대한 다양한 프로모션 및 관리가 필요할 수 있습니다. NULL 값은 번들 여부가 정의되지 않은 경우로, 데이터 정합성 확보 시 주의가 필요합니다.
#
# 3. 데이터 특성
# - 허용 값: 'Y'(번들 상품), NULL(번들 여부 미정)
# - NULL 허용: 약 87.56% (대부분이 번들 여부 미정)
# - 문자열 길이: 1자리
# - 고유값 : 2개 ('Y', NULL)
# - 비즈니스 시나리오에서 번들 상품의 식별에 활용됨'
# ✅ API 응답 수신 (길이: 369자)
#
# ✅ 총 34개 컬럼 메타데이터 생성 완료
#
# 생성된 메타데이터:
#                          column_name data_type null_ratio  unique_count  \
# 0             display_category_major    object      0.00%             8
# 1            display_category_middle    object      0.00%            41
# 2             display_category_minor    object      0.00%           183
# 3             product_category_major    object      0.00%            20
# 4            product_category_middle    object      0.00%            80
# 5             product_category_minor    object      0.00%           200
# 6                         model_name    object      2.78%          2120
# 7                         model_code    object      0.00%          2774
# 8                         product_id    object      0.00%          2774
# 9                       product_name    object      0.00%          1681
# 10                     product_color    object     15.07%           241
# 11                      release_date    object      1.37%            96
# 12       is_ai_subscription_eligible    object      0.00%             2
# 13    is_smart_subscription_eligible    object     93.76%             3
# 14           is_galaxy_club_eligible    object     98.34%             2
# 15  is_installment_payment_available    object      0.00%             2
# 16                product_detail_url    object      0.00%          2774
# 17                      channel_code    object    100.00%             1
# 18              unique_selling_point    object      3.89%           880
# 19                      review_count   float64      2.45%           246
# 20               review_rating_score   float64      2.45%           122
# 21                    standard_price   float64      0.00%           968
# 22                      member_price   float64      0.00%           966
# 23                     benefit_price   float64     38.21%           699
# 24            review_text_collection    object     36.66%          1750
# 25             product_specification    object     13.05%          2018
# 26                        is_on_sale    object    100.00%             1
# 27        web_coupon_discount_amount    object    100.00%             1
# 28                    stock_quantity   float64     82.05%           204
# 29       bundle_component_model_code    object     87.56%           346
# 30                         site_code    object      0.00%             1
# 31                       final_price   float64      0.00%           933
# 32                 is_bispokle_goods    object    100.00%             1
# 33                 is_bundle_product    object     87.56%             2
#
#                                           description  \
# 0   1. 짧은 설명  \n제품의 대분류 카테고리명\n\n2. 상세 설명  \n웹사이트에...
# 1   1. 짧은 설명:  \n제품 중분류 노출 카테고리명\n\n2. 상세 설명:  \n웹...
# 2   1. 짧은 설명 (한 줄, 20자 이내)  \n제품 소분류 카테고리명\n\n2. 상...
# 3   1. **짧은 설명 (20자 이내)**  \n제품 대분류 카테고리명\n\n2. **...
# 4   1. 짧은 설명 (20자 이내)  \n제품 중분류 카테고리명\n\n2. 상세 설명 ...
# 5   1. 짧은 설명 (한 줄, 20자 이내)  \n제품 소분류 카테고리\n\n2. 상세...
# 6   1. 짧은 설명 (20자 이내)  \n공식 제품 모델명 정보\n\n2. 상세 설명 ...
# 7   1. 짧은 설명  \n제품별 고유 모델 코드\n\n2. 상세 설명  \n각 제품의 ...
# 8   1. 짧은 설명 (20자 이내)  \n제품을 식별하는 고유 ID\n\n2. 상세 설...
# 9   1. 짧은 설명:  \n최종 웹사이트 제품명\n\n2. 상세 설명:  \n사용자에게...
# 10  1. 짧은 설명  \n제품의 색상명을 저장하는 컬럼\n\n2. 상세 설명  \npr...
# 11  1. 짧은 설명  \n제품의 공식 출시일(YYYY-MM-DD)\n\n2. 상세 설명...
# 12  1. 짧은 설명  \nAI 구독 서비스 가입 가능 여부\n\n2. 상세 설명  \n...
# 13  1. 짧은 설명  \n스마트 구독 서비스 가입 가능 여부\n\n2. 상세 설명  \...
# 14  1. 짧은 설명  \n갤럭시 클럽 혜택 가능 여부\n\n2. 상세 설명  \n해당 ...
# 15  1. 짧은 설명  \n할부 결제 가능 여부(Y/N) 표시\n\n2. 상세 설명  \...
# 16  1. 짧은 설명 (한 줄, 20자 이내)  \n제품 상세정보 URL\n\n2. 상세...
# 17  1. 짧은 설명  \n판매 채널 구분 코드\n\n2. 상세 설명  \n상품의 판매가...
# 18  1. 짧은 설명  \n제품의 주요 특장점 요약 문구\n\n2. 상세 설명  \nun...
# 19  1. 짧은 설명  \n해당 제품의 총 리뷰 개수\n\n2. 상세 설명  \n각 제품...
# 20  1. 짧은 설명 (한 줄, 20자 이내)  \n제품 평균 리뷰 평점\n\n2. 상세...
# 21  1. 짧은 설명  \n정상 판매 기준 가격\n\n2. 상세 설명  \n할인이나 프로...
# 22  1. 짧은 설명  \n삼성닷컴 회원 전용 할인가\n\n2. 상세 설명  \n이 컬럼...
# 23  1. 짧은 설명  \n모든 혜택 적용 후 최종가\n\n2. 상세 설명  \nbene...
# 24  1. 짧은 설명   \n상품별 사용자 리뷰 텍스트 모음\n\n2. 상세 설명  \n...
# 25  1. 짧은 설명 (한 줄, 20자 이내)  \n제품별 상세 기술 사양 정보\n\n2...
# 26  1. 짧은 설명  \n제품의 세일 진행 여부 표시\n\n2. 상세 설명  \n현재 ...
# 27  1. 짧은 설명  \n웹 쿠폰 할인 금액 정보\n\n2. 상세 설명  \n웹 쿠폰이...
# 28  1. 짧은 설명:  \n상품별 현재 판매 가능 재고 수량\n\n2. 상세 설명:  ...
# 29  1. 짧은 설명  \n번들 상품 구성품 모델 코드\n\n2. 상세 설명  \n이 컬...
# 30  1. 짧은 설명  \n판매 채널을 표시하는 코드입니다.\n\n2. 상세 설명  \n...
# 31  1. 짧은 설명  \n최종 결제 예상 금액\n\n2. 상세 설명  \nfinal_p...
# 32  1. 짧은 설명  \n비스포크 상품 여부 표시\n\n2. 상세 설명  \n해당 컬럼...
# 33  1. 짧은 설명  \n해당 상품이 번들 여부(Y/N)\n\n2. 상세 설명  \n'...
#
#                   generated_at     min         max          mean      median
# 0   2025-09-30T14:57:00.350985     NaN         NaN           NaN         NaN
# 1   2025-09-30T14:57:02.704395     NaN         NaN           NaN         NaN
# 2   2025-09-30T14:57:04.915654     NaN         NaN           NaN         NaN
# 3   2025-09-30T14:57:07.187803     NaN         NaN           NaN         NaN
# 4   2025-09-30T14:57:09.393099     NaN         NaN           NaN         NaN
# 5   2025-09-30T14:57:11.477644     NaN         NaN           NaN         NaN
# 6   2025-09-30T14:57:14.509848     NaN         NaN           NaN         NaN
# 7   2025-09-30T14:57:17.008379     NaN         NaN           NaN         NaN
# 8   2025-09-30T14:57:19.042116     NaN         NaN           NaN         NaN
# 9   2025-09-30T14:57:21.383073     NaN         NaN           NaN         NaN
# 10  2025-09-30T14:57:23.840128     NaN         NaN           NaN         NaN
# 11  2025-09-30T14:57:26.583053     NaN         NaN           NaN         NaN
# 12  2025-09-30T14:57:28.739843     NaN         NaN           NaN         NaN
# 13  2025-09-30T14:57:31.633230     NaN         NaN           NaN         NaN
# 14  2025-09-30T14:57:34.193201     NaN         NaN           NaN         NaN
# 15  2025-09-30T14:57:36.288871     NaN         NaN           NaN         NaN
# 16  2025-09-30T14:57:38.461552     NaN         NaN           NaN         NaN
# 17  2025-09-30T14:57:41.119552     NaN         NaN           NaN         NaN
# 18  2025-09-30T14:57:43.957572     NaN         NaN           NaN         NaN
# 19  2025-09-30T14:57:46.109889     0.0      8464.0  4.424183e+02       20.00
# 20  2025-09-30T14:57:48.542990     0.0         5.0  3.723899e+00        4.67
# 21  2025-09-30T14:57:50.795544  3300.0  52690000.0  1.890617e+06   676500.00
# 22  2025-09-30T14:57:52.985335  3300.0  52690000.0  1.890277e+06   676500.00
# 23  2025-09-30T14:57:56.093355  3000.0  50700000.0  2.177148e+06  1390000.00
# 24  2025-09-30T14:57:58.438565     NaN         NaN           NaN         NaN
# 25  2025-09-30T14:58:00.958615     NaN         NaN           NaN         NaN
# 26  2025-09-30T14:58:03.369341     NaN         NaN           NaN         NaN
# 27  2025-09-30T14:58:05.474393     NaN         NaN           NaN         NaN
# 28  2025-09-30T14:58:08.397854     0.0      9999.0  3.086693e+03      146.50
# 29  2025-09-30T14:58:11.361037     NaN         NaN           NaN         NaN
# 30  2025-09-30T14:58:13.651734     NaN         NaN           NaN         NaN
# 31  2025-09-30T14:58:15.807428  3000.0  50700000.0  1.523102e+06   569750.00
# 32  2025-09-30T14:58:18.313546     NaN         NaN           NaN         NaN
# 33  2025-09-30T14:58:21.183784     NaN         NaN           NaN         NaN

# %%
# 9. 테이블 전체 설명 생성
def generate_table_description(table_name='test', table_stats=None, column_stats=None):
    """테이블 전체에 대한 종합적인 설명 생성"""
    
    if not openai_client:
        return None
    
    # 주요 컬럼 정보 추출
    key_columns = []
    if column_stats is not None and len(column_stats) > 0:
        key_columns = column_stats.head(10)['column_name'].tolist()
    
    prompt = f"""
    다음 데이터베이스 테이블에 대한 종합적인 설명을 영어로 작성해주세요. 
    테이블은 삼성닷컴의 제품 정보를 담고 있습니다. 
    
    테이블명: {table_name}
    
    테이블 통계:
    - 전체 행 수: {table_stats.get('total_rows', 'N/A') if table_stats else 'N/A'}
    - 테이블 크기: {table_stats.get('table_size', 'N/A') if table_stats else 'N/A'}
    - 전체 컬럼 수: {len(column_stats) if column_stats is not None else 'N/A'}
    
    주요 컬럼: {', '.join(key_columns)}
    
    다음 내용을 포함하여 설명해주세요:
    1. 테이블의 주요 목적과 역할 (2-3줄)
    2. 저장되는 데이터의 비즈니스 의미
    3. 다른 테이블과의 잠재적 연관 관계
    4. 데이터 활용 사례 (예: 리포트, 분석, API 등)
    """
    
    try:
        print("--------")
        response = openai_client.chat.completions.create(
            model=os.getenv('DEPLOYMENT_NAME'),
            messages=[
                {"role": "system", "content": "당신은 데이터 아키텍트입니다. 테이블의 비즈니스 목적과 활용 방안을 명확하게 설명해주세요."},
                {"role": "user", "content": prompt}
            ],
            # temperature 파라미터 제거 (기본값 1 사용)
            max_completion_tokens=500
        )
        
        return response.choices[0].message.content
    
    except Exception as e:
        print(f"❌ 테이블 설명 생성 실패: {e}")
        return None

# 테이블 설명 생성
table_description = generate_table_description(
    table_name='kt_merged_product_20250929',
    table_stats=table_stats,
    column_stats=df_column_stats
)

if table_description:
    print("=" * 60)
    print("📋 kt_merged_product_20250929 테이블 설명")
    print("=" * 60)
    print(table_description)
    print("=" * 60)
# Out:
# --------
# ============================================================
# 📋 kt_merged_product_20250929 테이블 설명
# ============================================================
# **Table Name:** `kt_merged_product_20250929`
#
# 1. **Primary Purpose and Role:**
# The `kt_merged_product_20250929` table serves as a comprehensive repository of product information for Samsung.com, organizing detailed attributes necessary for managing, displaying, and analyzing product offerings.
#
# 2. **Business Significance of Stored Data:**
# This table contains granular product data, including hierarchical display and product categories (major, middle, minor), unique identifiers (product_id, model_code), and descriptors like model_name and product_name. Such information is crucial for categorizing, searching, and presenting products to customers, as well as tracking inventory and sales performance.
#
# 3. **Potential Relationships with Other Tables:**
# The table can be joined with related tables, such as sales transaction tables (using product_id), inventory management tables, customer interaction or review tables, and marketing campaign tables. These relationships enhance capabilities like cross-analysis of sales performance by category, detailed product analytics, and targeted marketing.
#
# 4. **Data Utilization Scenarios:**
# Typical use cases include generating product catalog reports, powering front-end APIs for product display and search features, conducting category-wise sales and inventory analysis, and feeding recommendation engines for personalized shopping experiences. The table is also pivotal for business intelligence efforts, enabling trend analysis and strategic decision-making based on comprehensive product data.
# ============================================================

# %%
# 10-1. 메타데이터 저장 (JSON, CSV 형식)
def save_metadata(df_metadata, table_description, table_name, output_dir='./metadata'):
    """생성된 메타데이터를 파일로 저장"""
    
    import os
    from datetime import datetime
    
    # 출력 디렉토리 생성
    os.makedirs(output_dir, exist_ok=True)
    
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    
    # 1. CSV 형식으로 컬럼 메타데이터 저장
    if df_metadata is not None:
        csv_path = os.path.join(output_dir, f'{table_name}_columns_{timestamp}.csv')
        df_metadata.to_csv(csv_path, index=False, encoding='utf-8-sig')
        print(f"✅ 컬럼 메타데이터 CSV 저장: {csv_path}")
    
    # 2. JSON 형식으로 전체 메타데이터 저장
    metadata_json = {
        'table_name': table_name,
        'generated_at': datetime.now().isoformat(),
        'table_description': table_description,
        'table_statistics': table_stats,
        'columns': df_metadata.to_dict('records') if df_metadata is not None else []
    }
    
    json_path = os.path.join(output_dir, f'{table_name}_metadata_{timestamp}.json')
    with open(json_path, 'w', encoding='utf-8') as f:
        json.dump(metadata_json, f, ensure_ascii=False, indent=2, default=str)
    print(f"✅ 전체 메타데이터 JSON 저장: {json_path}")
    
    # 3. 테이블 설명만 별도 텍스트 파일로 저장
    if table_description:
        txt_path = os.path.join(output_dir, f'{table_name}_description_{timestamp}.txt')
        with open(txt_path, 'w', encoding='utf-8') as f:
            f.write(f"{table_name} 테이블 설명\n")
            f.write("=" * 60 + "\n")
            f.write(f"생성일시: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            f.write("=" * 60 + "\n\n")
            f.write(table_description)
        print(f"✅ 테이블 설명 TXT 저장: {txt_path}")
    
    return {
        'csv_path': csv_path if df_metadata is not None else None,
        'json_path': json_path,
        'txt_path': txt_path if table_description else None
    }

# 메타데이터 저장
saved_files = save_metadata(df_metadata, table_description, table_name='kt_merged_product_20250929')
print("\n📁 저장된 파일:")
for key, path in saved_files.items():
    if path:
        print(f"  - {key}: {path}")
# Out:
# ✅ 컬럼 메타데이터 CSV 저장: ./metadata/kt_merged_product_20250929_columns_20250930_145824.csv
# ✅ 전체 메타데이터 JSON 저장: ./metadata/kt_merged_product_20250929_metadata_20250930_145824.json
# ✅ 테이블 설명 TXT 저장: ./metadata/kt_merged_product_20250929_description_20250930_145824.txt
#
# 📁 저장된 파일:
#   - csv_path: ./metadata/kt_merged_product_20250929_columns_20250930_145824.csv
#   - json_path: ./metadata/kt_merged_product_20250929_metadata_20250930_145824.json
#   - txt_path: ./metadata/kt_merged_product_20250929_description_20250930_145824.txt

# %%
# 10-2. 메타데이터 저장 (박종찬님 요청 NoSQL 형식 - JSONL)
def save_metadata_nosql_format(df_column_stats, df_metadata, table_name, output_dir='./metadata'):
    """NoSQL 형식으로 메타데이터를 JSONL 파일로 저장"""
    
    import os
    from datetime import datetime
    
    # 출력 디렉토리 생성
    os.makedirs(output_dir, exist_ok=True)
    
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    
    # JSONL 파일 경로
    jsonl_path = os.path.join(output_dir, f'{table_name}_metadata_nosql_{timestamp}.jsonl')
    
    nosql_records = []
    
    # 각 컬럼에 대한 NoSQL 형식 레코드 생성
    for idx, row in df_column_stats.iterrows():
        column_name = row['column_name']
        
        # df_metadata에서 생성된 설명 가져오기
        metadata_row = None
        if df_metadata is not None:
            metadata_matches = df_metadata[df_metadata['column_name'] == column_name]
            if not metadata_matches.empty:
                metadata_row = metadata_matches.iloc[0]
        
        # 설명 파싱 (생성된 설명이 있는 경우)
        short_desc = ""
        long_desc = ""
        data_desc = ""
        
        if metadata_row is not None and pd.notna(metadata_row.get('description')):
            description_text = metadata_row['description']
            # 설명을 줄별로 분리하여 파싱
            lines = description_text.split('\n')
            for i, line in enumerate(lines):
                if line.strip().startswith('1.'):
                    short_desc = line.replace('1.', '').strip()
                elif line.strip().startswith('2.'):
                    long_desc = line.replace('2.', '').strip()
                elif line.strip().startswith('3.'):
                    data_desc = line.replace('3.', '').strip()
        
        # 기본값 설정 (설명이 없는 경우)
        if not short_desc:
            short_desc = f"{column_name} 정보"
        if not long_desc:
            long_desc = f"{column_name} 컬럼에 저장되는 데이터입니다."
        if not data_desc:
            data_desc = f"데이터 타입: {row.get('data_type', 'unknown')}, NULL 비율: {row.get('null_ratio', 'N/A')}"
        
        # values 필드 처리 (수정된 부분)
        values_list = []
        values_field = row.get('values')
        
        # values가 None이 아니고 실제 값이 있는지 확인
        if values_field is not None:
            if isinstance(values_field, list):
                # 리스트인 경우 그대로 사용
                values_list = values_field[:15]  # 최대 15개로 제한
                # 문자열로 변환 (JSON 직렬화를 위해)
                values_list = [str(v) if not isinstance(v, (str, int, float)) else v for v in values_list]
            elif isinstance(values_field, dict):
                # dict인 경우 키만 추출
                values_list = list(values_field.keys())[:15]
            elif isinstance(values_field, (np.ndarray, pd.Series)):
                # numpy 배열이나 pandas Series인 경우
                values_list = values_field.tolist()[:15] if len(values_field) > 0 else []
                # 문자열로 변환
                values_list = [str(v) if not isinstance(v, (str, int, float)) else v for v in values_list]
        
        # most_common이 있으면 values로 사용 (values가 없는 경우)
        if not values_list:
            most_common = row.get('most_common')
            if most_common is not None and isinstance(most_common, dict) and len(most_common) > 0:
                values_list = list(most_common.keys())[:15]
        
        # column_type 결정 (PostgreSQL 스키마 정보 참조)
        column_type = row.get('data_type', 'unknown')
        if df_schema is not None:
            schema_match = df_schema[df_schema['column_name'] == column_name]
            if not schema_match.empty:
                schema_info = schema_match.iloc[0]
                data_type = schema_info.get('data_type', '')
                max_length = schema_info.get('character_maximum_length')
                numeric_precision = schema_info.get('numeric_precision')
                numeric_scale = schema_info.get('numeric_scale')
                
                # PostgreSQL 타입을 더 구체적으로 표현
                if pd.notna(max_length):
                    column_type = f"{data_type}({int(max_length)})"
                elif pd.notna(numeric_precision) and pd.notna(numeric_scale):
                    column_type = f"{data_type}({int(numeric_precision)},{int(numeric_scale)})"
                elif pd.notna(numeric_precision):
                    column_type = f"{data_type}({int(numeric_precision)})"
                else:
                    column_type = data_type
        
        # NoSQL 형식 레코드 생성
        nosql_record = {
            "table": table_name.replace("kt_merged_", "").replace("_20250929", ""),  # 테이블명 간소화
            "column": column_name,
            "column_type": column_type,
            "comment": row.get('column_comment', '') if pd.notna(row.get('column_comment')) else "",
            "short_description": short_desc,
            "long_description": long_desc,
            "data_description": data_desc,
            "values": values_list,
            "sql_use": "Y",  # 기본값 Y
            "synonyms": []  # 빈 리스트로 초기화
        }
        
        # 추가 통계 정보 (선택적)
        nosql_record["statistics"] = {
            "null_ratio": row.get('null_ratio', 'N/A'),
            "unique_count": int(row.get('unique_count')) if pd.notna(row.get('unique_count')) else None,
            "unique_ratio": row.get('unique_ratio', 'N/A')
        }
        
        # 수치형 데이터인 경우 통계 추가
        if pd.notna(row.get('min')):
            nosql_record["statistics"].update({
                "min": float(row.get('min')) if pd.notna(row.get('min')) else None,
                "max": float(row.get('max')) if pd.notna(row.get('max')) else None,
                "mean": float(row.get('mean')) if pd.notna(row.get('mean')) else None,
                "median": float(row.get('median')) if pd.notna(row.get('median')) else None,
                "std": float(row.get('std')) if pd.notna(row.get('std')) else None
            })
        
        # 문자열 데이터인 경우 길이 통계 추가
        if pd.notna(row.get('min_length')):
            nosql_record["statistics"].update({
                "min_length": int(row.get('min_length')) if pd.notna(row.get('min_length')) else None,
                "max_length": int(row.get('max_length')) if pd.notna(row.get('max_length')) else None,
                "avg_length": float(row.get('avg_length')) if pd.notna(row.get('avg_length')) else None
            })
        
        # 날짜형 데이터인 경우 날짜 범위 추가
        if pd.notna(row.get('min_date')):
            nosql_record["statistics"].update({
                "min_date": str(row.get('min_date')) if pd.notna(row.get('min_date')) else None,
                "max_date": str(row.get('max_date')) if pd.notna(row.get('max_date')) else None,
                "date_range": str(row.get('date_range')) if pd.notna(row.get('date_range')) else None
            })
        
        nosql_records.append(nosql_record)
    
    # JSONL 형식으로 저장 (각 줄에 하나의 JSON 객체)
    with open(jsonl_path, 'w', encoding='utf-8') as f:
        for record in nosql_records:
            # 각 레코드를 한 줄에 저장
            json_line = json.dumps(record, ensure_ascii=False, default=str)
            f.write(json_line + '\n')
    
    print(f"✅ NoSQL 형식 메타데이터 JSONL 저장: {jsonl_path}")
    print(f"   - 총 {len(nosql_records)}개 컬럼 레코드 저장")
    
    # 샘플 출력
    if nosql_records:
        print("\n📋 샘플 레코드 (첫 번째 컬럼):")
        print(json.dumps(nosql_records[0], ensure_ascii=False, indent=2, default=str))
    
    return jsonl_path

# NoSQL 형식으로 메타데이터 저장
if df_column_stats is not None:
    jsonl_file_path = save_metadata_nosql_format(
        df_column_stats=df_column_stats,
        df_metadata=df_metadata,
        table_name='kt_merged_product_20250929'
    )
    print(f"\n✅ JSONL 파일 생성 완료: {jsonl_file_path}")
# Out:
# ✅ NoSQL 형식 메타데이터 JSONL 저장: ./metadata/kt_merged_product_20250929_metadata_nosql_20250930_145824.jsonl
#    - 총 34개 컬럼 레코드 저장
#
# 📋 샘플 레코드 (첫 번째 컬럼):
# {
#   "table": "product",
#   "column": "display_category_major",
#   "column_type": "character varying(1000)",
#   "comment": "웹사이트에 노출되는 제품의 대분류 카테고리명입니다. (예: 모바일, TV & 오디오, 가전)",
#   "short_description": "짧은 설명",
#   "long_description": "상세 설명",
#   "data_description": "데이터 특성",
#   "values": [
#     "모바일",
#     "리빙가전",
#     "TV",
#     "PC/주변기기",
#     "주방가전",
#     "오디오",
#     "아울렛",
#     "MD 초이스 샵"
#   ],
#   "sql_use": "Y",
#   "synonyms": [],
#   "statistics": {
#     "null_ratio": "0.00%",
#     "unique_count": 8,
#     "unique_ratio": "0.29%",
#     "min_length": 2,
#     "max_length": 8,
#     "avg_length": 3.782624369142033
#   }
# }
#
# ✅ JSONL 파일 생성 완료: ./metadata/kt_merged_product_20250929_metadata_nosql_20250930_145824.jsonl

# %%
# 10-3. 메타데이터 저장 (MongoDB - 선택된 컬럼만)
def save_metadata_to_mongodb(df_column_stats, df_metadata, table_name, selected_columns, collection_name, output_dir='./metadata'):
    """선택된 컬럼들의 메타데이터를 MongoDB에 저장"""
    
    import os
    import pymongo
    from datetime import datetime
    from dotenv import load_dotenv
    
    load_dotenv('.env')
    
    # MongoDB 연결 문자열 가져오기
    CONNECTION_STRING = os.getenv('COSMOS_CONNECTION_STRING') or os.getenv('MONGODB_CONNECTION_STRING')
    
    if not CONNECTION_STRING:
        print("❌ MongoDB 연결 문자열을 찾을 수 없습니다.")
        print("   .env 파일에 COSMOS_CONNECTION_STRING 또는 MONGODB_CONNECTION_STRING을 설정해주세요.")
        return False
    
    try:
        # MongoDB 클라이언트 생성
        print(f"\n📡 MongoDB 연결 시도...")
        client = pymongo.MongoClient(CONNECTION_STRING)
        
        # 연결 테스트
        client.admin.command('ping')
        print(f"✅ MongoDB 연결 성공")
        
        # 데이터베이스 선택 (연결 문자열에서 추출하거나 기본값 사용)
        db_name = "rubicon"  # 기본 데이터베이스 이름
        
        # 연결 문자열에서 데이터베이스 이름 추출 시도
        if '/' in CONNECTION_STRING and '?' in CONNECTION_STRING:
            try:
                db_name_from_conn = CONNECTION_STRING.split('/')[-1].split('?')[0]
                if db_name_from_conn:
                    db_name = db_name_from_conn
            except:
                pass
        
        db = client[db_name]
        collection = db[collection_name]
        
        print(f"📂 데이터베이스: {db_name}")
        print(f"📁 컬렉션: {collection_name}")
        print(f"🎯 선택된 컬럼 수: {len(selected_columns)}")
        
        # 선택된 컬럼들의 메타데이터 준비
        documents = []
        inserted_count = 0
        
        for column_name in selected_columns:
            # df_column_stats에서 해당 컬럼 정보 찾기
            column_stats = df_column_stats[df_column_stats['column_name'] == column_name]
            
            if column_stats.empty:
                print(f"  ⚠️ 컬럼 '{column_name}'을(를) 통계 데이터에서 찾을 수 없습니다.")
                continue
            
            row = column_stats.iloc[0]
            
            # df_metadata에서 생성된 설명 가져오기
            metadata_row = None
            if df_metadata is not None:
                metadata_matches = df_metadata[df_metadata['column_name'] == column_name]
                if not metadata_matches.empty:
                    metadata_row = metadata_matches.iloc[0]
            
            # 설명 파싱 (인덱스 기반 파싱으로 수정)
            short_desc = ""
            long_desc = ""
            data_desc = ""
            
            if metadata_row is not None and pd.notna(metadata_row.get('description')):
                description_text = metadata_row['description']
                lines = description_text.split('\n')
                
                # 인덱스 기반으로 파싱 (빈 줄 포함하여 정확한 위치)
                try:
                    # short_description: 인덱스 1 (0부터 시작, 두 번째 줄)
                    if len(lines) > 1:
                        short_desc = lines[1].strip()
                        # "1. " 제거
                        if short_desc.startswith('1.'):
                            short_desc = short_desc[2:].strip()
                    
                    # long_description: 인덱스 4 (다섯 번째 줄)
                    if len(lines) > 4:
                        long_desc = lines[4].strip()
                        # "2. " 제거
                        if long_desc.startswith('2.'):
                            long_desc = long_desc[2:].strip()
                    
                    # data_description: 인덱스 7 (여덟 번째 줄)
                    if len(lines) > 7:
                        data_desc = lines[7].strip()
                        # "3. " 제거
                        if data_desc.startswith('3.'):
                            data_desc = data_desc[2:].strip()
                        
                except Exception as e:
                    print(f"  ⚠️ 설명 파싱 실패 ({column_name}): {e}")
                    # 파싱 실패 시 전체 줄을 순회하며 번호로 찾기 (백업 방법)
                    for line in lines:
                        line_strip = line.strip()
                        if line_strip.startswith('1.') and not short_desc:
                            short_desc = line_strip[2:].strip()
                        elif line_strip.startswith('2.') and not long_desc:
                            long_desc = line_strip[2:].strip()
                        elif line_strip.startswith('3.') and not data_desc:
                            data_desc = line_strip[2:].strip()
            
            # 기본값 설정 (설명이 없는 경우)
            if not short_desc:
                short_desc = f"{column_name} 정보"
            if not long_desc:
                long_desc = f"{column_name} 컬럼에 저장되는 데이터입니다."
            if not data_desc:
                data_desc = f"데이터 타입: {row.get('data_type', 'unknown')}, NULL 비율: {row.get('null_ratio', 'N/A')}"
            
            # values 필드 처리
            values_list = []
            values_field = row.get('values')
            
            if values_field is not None:
                if isinstance(values_field, list):
                    values_list = values_field[:15]
                    values_list = [str(v) if not isinstance(v, (str, int, float)) else v for v in values_list]
                elif isinstance(values_field, (np.ndarray, pd.Series)):
                    values_list = values_field.tolist()[:15] if len(values_field) > 0 else []
                    values_list = [str(v) if not isinstance(v, (str, int, float)) else v for v in values_list]
            
            # most_common 대체
            if not values_list:
                most_common = row.get('most_common')
                if most_common is not None and isinstance(most_common, dict) and len(most_common) > 0:
                    values_list = list(most_common.keys())[:15]
            
            # column_type 결정
            column_type = row.get('data_type', 'unknown')
            if df_schema is not None:
                schema_match = df_schema[df_schema['column_name'] == column_name]
                if not schema_match.empty:
                    schema_info = schema_match.iloc[0]
                    data_type = schema_info.get('data_type', '')
                    max_length = schema_info.get('character_maximum_length')
                    numeric_precision = schema_info.get('numeric_precision')
                    numeric_scale = schema_info.get('numeric_scale')
                    
                    if pd.notna(max_length):
                        column_type = f"{data_type}({int(max_length)})"
                    elif pd.notna(numeric_precision) and pd.notna(numeric_scale):
                        column_type = f"{data_type}({int(numeric_precision)},{int(numeric_scale)})"
                    elif pd.notna(numeric_precision):
                        column_type = f"{data_type}({int(numeric_precision)})"
                    else:
                        column_type = data_type
            
            # MongoDB 문서 생성
            document = {
                "_id": f"{table_name}_{column_name}",  # 고유 ID
                "table": table_name.replace("kt_merged_", "").replace("_20250929", ""),
                "column": column_name,
                "column_type": column_type,
                "comment": row.get('column_comment', '') if pd.notna(row.get('column_comment')) else "",
                "short_description": short_desc,
                "long_description": long_desc,
                "data_description": data_desc,
                "values": values_list,
                "sql_use": "Y",
                "synonyms": [],
                "statistics": {
                    "null_ratio": row.get('null_ratio', 'N/A'),
                    "unique_count": int(row.get('unique_count')) if pd.notna(row.get('unique_count')) else None,
                    "unique_ratio": row.get('unique_ratio', 'N/A')
                },
                "created_at": datetime.now(),
                "updated_at": datetime.now()
            }
            
            # 추가 통계 정보
            if pd.notna(row.get('min')):
                document["statistics"].update({
                    "min": float(row.get('min')) if pd.notna(row.get('min')) else None,
                    "max": float(row.get('max')) if pd.notna(row.get('max')) else None,
                    "mean": float(row.get('mean')) if pd.notna(row.get('mean')) else None,
                    "median": float(row.get('median')) if pd.notna(row.get('median')) else None,
                    "std": float(row.get('std')) if pd.notna(row.get('std')) else None
                })
            
            if pd.notna(row.get('min_length')):
                document["statistics"].update({
                    "min_length": int(row.get('min_length')) if pd.notna(row.get('min_length')) else None,
                    "max_length": int(row.get('max_length')) if pd.notna(row.get('max_length')) else None,
                    "avg_length": float(row.get('avg_length')) if pd.notna(row.get('avg_length')) else None
                })
            
            documents.append(document)
        
        # MongoDB에 삽입 (upsert: 있으면 업데이트, 없으면 삽입)
        if documents:
            print(f"\n📝 {len(documents)}개 문서를 MongoDB에 저장 중...")
            
            for doc in documents:
                try:
                    # upsert 방식으로 저장
                    result = collection.replace_one(
                        {"_id": doc["_id"]},
                        doc,
                        upsert=True
                    )
                    
                    if result.upserted_id:
                        print(f"  ✅ 삽입: {doc['column']}")
                    else:
                        print(f"  🔄 업데이트: {doc['column']}")
                    
                    inserted_count += 1
                    
                except Exception as e:
                    print(f"  ❌ 실패: {doc['column']} - {str(e)}")
            
            print(f"\n✅ 총 {inserted_count}개 문서 저장 완료")
            
            # 저장된 데이터 확인
            total_count = collection.count_documents({})
            print(f"📊 컬렉션 '{collection_name}'의 전체 문서 수: {total_count}")
            
            # 샘플 문서 출력
            sample_doc = collection.find_one({"table": table_name.replace("kt_merged_", "").replace("_20250929", "")})
            if sample_doc:
                print(f"\n📋 샘플 문서:")
                # _id와 날짜 필드는 문자열로 변환하여 출력
                sample_doc['_id'] = str(sample_doc['_id'])
                sample_doc['created_at'] = str(sample_doc.get('created_at', ''))
                sample_doc['updated_at'] = str(sample_doc.get('updated_at', ''))
                print(json.dumps(sample_doc, ensure_ascii=False, indent=2))
        else:
            print("⚠️ 저장할 문서가 없습니다.")
            return False
        
        # 선택적: JSON 백업 파일도 생성
        if output_dir:
            os.makedirs(output_dir, exist_ok=True)
            timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
            backup_path = os.path.join(output_dir, f'{collection_name}_mongodb_backup_{timestamp}.json')
            
            # datetime 객체를 문자열로 변환
            backup_docs = []
            for doc in documents:
                backup_doc = doc.copy()
                backup_doc['created_at'] = str(doc['created_at'])
                backup_doc['updated_at'] = str(doc['updated_at'])
                backup_docs.append(backup_doc)
            
            with open(backup_path, 'w', encoding='utf-8') as f:
                json.dump(backup_docs, f, ensure_ascii=False, indent=2, default=str)
            
            print(f"💾 백업 파일 저장: {backup_path}")
        
        return True
        
    except pymongo.errors.ServerSelectionTimeoutError:
        print("❌ MongoDB 연결 시간 초과")
        print("   연결 문자열과 네트워크 설정을 확인해주세요.")
        return False
        
    except pymongo.errors.OperationFailure as e:
        print(f"❌ MongoDB 작업 실패: {str(e)}")
        print("   권한 설정을 확인해주세요.")
        return False
        
    except Exception as e:
        print(f"❌ 예상치 못한 오류: {str(e)}")
        import traceback
        traceback.print_exc()
        return False
        
    finally:
        if 'client' in locals():
            client.close()
            print("🔌 MongoDB 연결 종료")

# 선택된 컬럼 목록 정의
selected_columns = [
    'display_category_middle',
    'display_category_minor', 
    'product_category_major',
    'model_name',
    'release_date',
    'product_name',
    'product_color',
    'review_count',
    'review_rating_score',
    'standard_price',
    'member_price',
    'benefit_price',
    'web_coupon_discount_amount',
    'final_price',
    'is_bundle_product',
    'bundle_component_model_code'
]

# MongoDB에 메타데이터 저장
if df_column_stats is not None:
    print("=" * 60)
    print("MongoDB에 선택된 컬럼 메타데이터 저장")
    print("=" * 60)
    
    success = save_metadata_to_mongodb(
        df_column_stats=df_column_stats,
        df_metadata=df_metadata,
        table_name='kt_merged_product_20250929',
        selected_columns=selected_columns,
        collection_name='synonyms_20250929'  # 컬렉션 이름을 여기서 지정
    )
    
    if success:
        print("\n✅ MongoDB 저장 작업 완료")
    else:
        print("\n❌ MongoDB 저장 작업 실패")
# Out:
# ============================================================
# MongoDB에 선택된 컬럼 메타데이터 저장
# ============================================================
#
# 📡 MongoDB 연결 시도...
# ✅ MongoDB 연결 성공
# 📂 데이터베이스: rubicon
# 📁 컬렉션: synonyms_20250929
# 🎯 선택된 컬럼 수: 16
#
# 📝 16개 문서를 MongoDB에 저장 중...
#   ✅ 삽입: display_category_middle
#   ✅ 삽입: display_category_minor
#   ✅ 삽입: product_category_major
#   ✅ 삽입: model_name
#   ✅ 삽입: release_date
#   ✅ 삽입: product_name
#   ✅ 삽입: product_color
#   ✅ 삽입: review_count
#   ✅ 삽입: review_rating_score
#   ✅ 삽입: standard_price
#   ✅ 삽입: member_price
#   ✅ 삽입: benefit_price
#   ✅ 삽입: web_coupon_discount_amount
#   ✅ 삽입: final_price
#   ✅ 삽입: is_bundle_product
#   ✅ 삽입: bundle_component_model_code
#
# ✅ 총 16개 문서 저장 완료
# 📊 컬렉션 'synonyms_20250929'의 전체 문서 수: 16
#
# 📋 샘플 문서:
# {
#   "_id": "kt_merged_product_20250929_display_category_middle",
#   "table": "product",
#   "column": "display_category_middle",
#   "column_type": "character varying(1000)",
#   "comment": "웹사이트에 노출되는 제품의 중분류 카테고리명입니다. (예: 스마트폰, QLED, 비스포크)",
#   "short_description": "제품 중분류 노출 카테고리명",
#   "long_description": "웹사이트에 노출되는 제품의 중분류 카테고리명을 나타냅니다. 'display_category_middle'은 제품을 고객이 쉽게 탐색할 수 있도록 스마트폰, TV, 갤럭시 액세서리 등 41개의 중분류로 구분하는 역할을 합니다. 비즈니스에서는 제품군별 마케팅, 상품 관리 및 분석에 활용됩니다.",
#   "data_description": "NULL 값은 허용되지 않으며(0.00%), 현재 41개의 고유값이 존재합니다. 값의 문자열 길이는 최소 2자, 최대 18자, 평균 6.8자입니다. 가장 빈번한 값으로는 '갤럭시 액세서리'(455건), 'TV'(347건), '시스템에어컨'(192건)이 포함됩니다.",
#   "values": [
#     "갤럭시 액세서리",
#     "TV",
#     "시스템에어컨",
#     "갤럭시 스마트폰",
#     "토너 및 잉크",
#     "주방가전 소모품/액세서리",
#     "JBLㅣ하만카돈ㅣAKGㅣ마크레빈슨",
#     "리빙가전 소모품/액세서리",
#     "세탁기",
#     "냉장고",
#     "모니터",
#     "메모리/스토리지",
#     "TV 액세서리",
#     "김치냉장고",
#     "갤럭시 북"
#   ],
#   "sql_use": "Y",
#   "synonyms": [],
#   "statistics": {
#     "null_ratio": "0.00%",
#     "unique_count": 41,
#     "unique_ratio": "1.48%",
#     "min_length": 2,
#     "max_length": 18,
#     "avg_length": 6.776135544340303
#   },
#   "created_at": "2025-09-30 14:59:09.765000",
#   "updated_at": "2025-09-30 14:59:09.765000"
# }
# 💾 백업 파일 저장: ./metadata/synonyms_20250929_mongodb_backup_20250930_145911.json
# 🔌 MongoDB 연결 종료
#
# ✅ MongoDB 저장 작업 완료

# %%
# 11. 메타데이터 데이터베이스 저장 (선택사항)
def save_metadata_to_db(df_metadata, table_description, target_table='table_metadata', table_name='test'):
    """생성된 메타데이터를 데이터베이스에 저장"""
    
    conn = get_db_connection()
    if not conn:
        return False
    
    try:
        cursor = conn.cursor()
        
        # 메타데이터 테이블 생성 (없는 경우)
        create_table_query = f"""
        CREATE TABLE IF NOT EXISTS {target_table} (
            id SERIAL PRIMARY KEY,
            table_name VARCHAR(255),
            column_name VARCHAR(255),
            data_type VARCHAR(100),
            null_ratio VARCHAR(20),
            unique_count INTEGER,
            min_value TEXT,
            max_value TEXT,
            mean_value NUMERIC,
            median_value NUMERIC,
            description TEXT,
            created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        );
        """
        cursor.execute(create_table_query)
        
        # 테이블 설명 저장용 테이블
        create_desc_table_query = """
        CREATE TABLE IF NOT EXISTS table_descriptions (
            id SERIAL PRIMARY KEY,
            table_name VARCHAR(255) UNIQUE,
            description TEXT,
            total_rows BIGINT,
            table_size VARCHAR(50),
            created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        );
        """
        cursor.execute(create_desc_table_query)
        
        # 기존 데이터 삭제 (중복 방지)
        cursor.execute(f"DELETE FROM {target_table} WHERE table_name = '{table_name}'")
        
        # 컬럼 메타데이터 삽입
        if df_metadata is not None:
            for _, row in df_metadata.iterrows():
                insert_query = f"""
                INSERT INTO {target_table} 
                (table_name, column_name, data_type, null_ratio, unique_count, 
                 min_value, max_value, mean_value, median_value, description)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                """
                cursor.execute(insert_query, (
                    table_name,
                    row.get('column_name'),
                    row.get('data_type'),
                    row.get('null_ratio'),
                    row.get('unique_count'),
                    str(row.get('min')) if 'min' in row else None,
                    str(row.get('max')) if 'max' in row else None,
                    row.get('mean') if 'mean' in row else None,
                    row.get('median') if 'median' in row else None,
                    row.get('description')
                ))
        
        # 테이블 설명 저장/업데이트
        if table_description and table_stats:
            upsert_query = """
            INSERT INTO table_descriptions (table_name, description, total_rows, table_size)
            VALUES (%s, %s, %s, %s)
            ON CONFLICT (table_name) 
            DO UPDATE SET 
                description = EXCLUDED.description,
                total_rows = EXCLUDED.total_rows,
                table_size = EXCLUDED.table_size,
                updated_at = CURRENT_TIMESTAMP
            """
            cursor.execute(upsert_query, (
                table_name,
                table_description,
                table_stats.get('total_rows'),
                table_stats.get('table_size')
            ))
        
        conn.commit()
        print(f"✅ 메타데이터가 데이터베이스에 저장되었습니다.")
        return True
        
    except Exception as e:
        print(f"❌ 데이터베이스 저장 실패: {e}")
        conn.rollback()
        return False
        
    finally:
        cursor.close()
        conn.close()

# 데이터베이스에 저장
if df_metadata is not None:
    save_metadata_to_db(df_metadata, table_description, table_name='kt_merged_product_20250929')

# %% [markdown]
# ## 요약
#
# 이 노트북은 `sr_merged_product` 테이블에 대한 메타데이터를 생성하고 저장합니다.
#
# ### 수행된 작업:
# 1. ✅ PostgreSQL 연결 설정
# 2. ✅ Azure OpenAI 클라이언트 구성
# 3. ✅ 테이블 스키마 정보 조회
# 4. ✅ 테이블 통계 정보 수집 (행 수, 크기 등)
# 5. ✅ 컬럼별 상세 통계 분석
# 6. ✅ Azure OpenAI를 활용한 컬럼 설명 생성
# 7. ✅ 테이블 전체 설명 생성
# 8. ✅ 메타데이터 파일 저장 (CSV, JSON, TXT)
# 9. ✅ 데이터베이스에 메타데이터 저장
#
# ### 다음 단계:
# - 전체 컬럼에 대한 메타데이터 생성 (현재는 10개만 처리)
# - 데이터 품질 검증 규칙 추가
# - 비즈니스 용어 사전과 연계
# - 다른 테이블에 대한 메타데이터 생성
